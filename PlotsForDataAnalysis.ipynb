# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

SNP = pd.read_csv('./SPX_500_Data.csv')

SNP.plot(x="Date", y=["Open","Close","Low", "High"], kind="line", figsize=(9, 8))
SNP.plot(x="Date", y="Volume", kind="line", figsize=(9, 8))
# SNP.plot(x="Date", y="% Gain/Loss (Close)", kind="line", figsize=(9, 8))
# SNP.plot(x="Date", y="% Price Variation", kind="line", figsize=(9, 8))
# Out:
# <AxesSubplot:xlabel='Date'>

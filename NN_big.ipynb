# %%
import math
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import classification_report
# from sklearn.metrics import accuracy_score, precision_score, recall_score
import tensorflow as tf
from keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Preprocessing

# %%
# Hyperparameters

# y column normalize scaler
normalizer_constant = 2

# time series step size
time_step = 45

# NN parameters
learning_rate = 0.1
num_epoch = 500
NN_layer_dimension = [100,100]
train_size = 568 # 80% of the data

# %%
# SNP = pd.read_csv('./SP500.csv')
SNP = pd.read_csv('./SPX_500_Data.csv')
SNP = SNP.drop(['Adj Close', 'Date','% Gain/Loss (Close)','% Price Variation'], axis=1)
# get all attributes
SNP_attributes = SNP.iloc[:,:]
# get last column (y)
# SNP_price = SNP.iloc[:,4:]
SNP_price = SNP['Close']
SNP_price = np.array(SNP_price)
SNP_price = np.reshape(SNP_price, (-1,1))

# normalize the data using MinMax scaller
scaler = MinMaxScaler()
scaler.fit(SNP_attributes)
SNP_attributes = scaler.transform(SNP_attributes)

Price_scaler = MinMaxScaler()
Price_scaler.fit(SNP_price)
SNP_price = Price_scaler.transform(SNP_price)


# scale data to [0,1]
# SNP_price = (SNP_price-SNP_price.min())/((SNP_price.max()*normalizer_constant)-SNP_price.min())

train_data = SNP_price[:, :]

train_data_mul = SNP_attributes[:, :]
# train_data_mul = np.array(train_data_mul)

# univariate
def create_train_data(data):
    x = []
    y = []
    for i in range(time_step, len(data)):
        x.append(data[i-time_step:i,0])
        y.append(data[i,0])
    return x, y

# multivariate
def create_train_data_mul(data):
    x = []
    y = []
    for i in range(time_step, len(data)):
        x.append(data[i-time_step:i, 0:data.shape[1]])
        y.append(data[i:i+1,3])
    return x, y

# X_train, y_train = create_train_data(train_data_mul)
X_train, y_train = create_train_data_mul(train_data_mul)

# %%
# Reshaping 
X_train, y_train = np.array(X_train), np.array(y_train)
#X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
# NN 
def create_model(units=[12,3], learning_rate=0.3):
    model = tf.keras.models.Sequential()
    # LSTM RNN model
    model.add(LSTM(units=64,return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Dropout(0.2))
    model.add(LSTM(units=64,return_sequences=False))
    model.add(Dropout(0.2))
    model.add(Dense(32,activation='tanh'))
    model.add(Dense(1))

    # opt = tf.keras.optimizers.SGD(learning_rate=0.1,momentum=0.9)
    model.compile(optimizer='adam',loss='mean_squared_error')

    return model

model = create_model(units=NN_layer_dimension, learning_rate=learning_rate)

# %%
# Train
model.fit(X_train, y_train, epochs=num_epoch, batch_size=36, verbose=2)
# Out:
# Epoch 1/500
# 417/417 - 10s - loss: 8.5313e-04 - 10s/epoch - 24ms/step
# Epoch 2/500
# 417/417 - 9s - loss: 3.4910e-04 - 9s/epoch - 22ms/step
# Epoch 3/500
# 417/417 - 9s - loss: 3.4553e-04 - 9s/epoch - 22ms/step
# Epoch 4/500
# 417/417 - 9s - loss: 3.0950e-04 - 9s/epoch - 22ms/step
# Epoch 5/500
# 417/417 - 9s - loss: 3.1747e-04 - 9s/epoch - 21ms/step
# Epoch 6/500
# 417/417 - 9s - loss: 2.7987e-04 - 9s/epoch - 21ms/step
# Epoch 7/500
# 417/417 - 9s - loss: 2.9363e-04 - 9s/epoch - 21ms/step
# Epoch 8/500
# 417/417 - 9s - loss: 2.9738e-04 - 9s/epoch - 21ms/step
# Epoch 9/500
# 417/417 - 9s - loss: 2.9404e-04 - 9s/epoch - 21ms/step
# Epoch 10/500
# 417/417 - 9s - loss: 2.9380e-04 - 9s/epoch - 21ms/step
# Epoch 11/500
# 417/417 - 9s - loss: 2.7290e-04 - 9s/epoch - 22ms/step
# Epoch 12/500
# 417/417 - 9s - loss: 3.0705e-04 - 9s/epoch - 21ms/step
# Epoch 13/500
# 417/417 - 9s - loss: 2.5995e-04 - 9s/epoch - 21ms/step
# Epoch 14/500
# 417/417 - 9s - loss: 2.6605e-04 - 9s/epoch - 21ms/step
# Epoch 15/500
# 417/417 - 9s - loss: 2.6633e-04 - 9s/epoch - 21ms/step
# Epoch 16/500
# 417/417 - 9s - loss: 2.6442e-04 - 9s/epoch - 21ms/step
# Epoch 17/500
# 417/417 - 9s - loss: 2.8626e-04 - 9s/epoch - 21ms/step
# Epoch 18/500
# 417/417 - 9s - loss: 2.4803e-04 - 9s/epoch - 21ms/step
# Epoch 19/500
# 417/417 - 9s - loss: 2.5975e-04 - 9s/epoch - 21ms/step
# Epoch 20/500
# 417/417 - 9s - loss: 2.2774e-04 - 9s/epoch - 22ms/step
# Epoch 21/500
# 417/417 - 9s - loss: 2.4480e-04 - 9s/epoch - 21ms/step
# Epoch 22/500
# 417/417 - 9s - loss: 1.9947e-04 - 9s/epoch - 21ms/step
# Epoch 23/500
# 417/417 - 9s - loss: 2.3291e-04 - 9s/epoch - 21ms/step
# Epoch 24/500
# 417/417 - 9s - loss: 2.2618e-04 - 9s/epoch - 21ms/step
# Epoch 25/500
# 417/417 - 9s - loss: 2.0179e-04 - 9s/epoch - 21ms/step
# Epoch 26/500
# 417/417 - 8s - loss: 2.1031e-04 - 8s/epoch - 20ms/step
# Epoch 27/500
# 417/417 - 9s - loss: 1.8136e-04 - 9s/epoch - 21ms/step
# Epoch 28/500
# 417/417 - 9s - loss: 1.8047e-04 - 9s/epoch - 21ms/step
# Epoch 29/500
# 417/417 - 9s - loss: 1.8053e-04 - 9s/epoch - 21ms/step
# Epoch 30/500
# 417/417 - 9s - loss: 1.8385e-04 - 9s/epoch - 21ms/step
# Epoch 31/500
# 417/417 - 9s - loss: 1.8359e-04 - 9s/epoch - 21ms/step
# Epoch 32/500
# 417/417 - 9s - loss: 1.7487e-04 - 9s/epoch - 21ms/step
# Epoch 33/500
# 417/417 - 8s - loss: 1.5492e-04 - 8s/epoch - 20ms/step
# Epoch 34/500
# 417/417 - 9s - loss: 1.5568e-04 - 9s/epoch - 21ms/step
# Epoch 35/500
# 417/417 - 9s - loss: 1.6208e-04 - 9s/epoch - 21ms/step
# Epoch 36/500
# 417/417 - 9s - loss: 1.5338e-04 - 9s/epoch - 20ms/step
# Epoch 37/500
# 417/417 - 9s - loss: 1.4571e-04 - 9s/epoch - 21ms/step
# Epoch 38/500
# 417/417 - 9s - loss: 1.5429e-04 - 9s/epoch - 21ms/step
# Epoch 39/500
# 417/417 - 8s - loss: 1.5108e-04 - 8s/epoch - 20ms/step
# Epoch 40/500
# 417/417 - 9s - loss: 1.3425e-04 - 9s/epoch - 20ms/step
# Epoch 41/500
# 417/417 - 9s - loss: 1.3091e-04 - 9s/epoch - 21ms/step
# Epoch 42/500
# 417/417 - 9s - loss: 1.2137e-04 - 9s/epoch - 21ms/step
# Epoch 43/500
# 417/417 - 9s - loss: 1.2417e-04 - 9s/epoch - 21ms/step
# Epoch 44/500
# 417/417 - 9s - loss: 1.2884e-04 - 9s/epoch - 21ms/step
# Epoch 45/500
# 417/417 - 9s - loss: 1.2308e-04 - 9s/epoch - 21ms/step
# Epoch 46/500
# 417/417 - 9s - loss: 1.1293e-04 - 9s/epoch - 21ms/step
# Epoch 47/500
# 417/417 - 9s - loss: 1.0979e-04 - 9s/epoch - 21ms/step
# Epoch 48/500
# 417/417 - 9s - loss: 1.0456e-04 - 9s/epoch - 21ms/step
# Epoch 49/500
# 417/417 - 9s - loss: 1.1318e-04 - 9s/epoch - 21ms/step
# Epoch 50/500
# 417/417 - 9s - loss: 1.0773e-04 - 9s/epoch - 22ms/step
# Epoch 51/500
# 417/417 - 9s - loss: 1.0959e-04 - 9s/epoch - 22ms/step
# Epoch 52/500
# 417/417 - 9s - loss: 9.9213e-05 - 9s/epoch - 21ms/step
# Epoch 53/500
# 417/417 - 9s - loss: 9.8039e-05 - 9s/epoch - 21ms/step
# Epoch 54/500
# 417/417 - 9s - loss: 1.0390e-04 - 9s/epoch - 20ms/step
# Epoch 55/500
# 417/417 - 9s - loss: 9.3321e-05 - 9s/epoch - 21ms/step
# Epoch 56/500
# 417/417 - 9s - loss: 9.8200e-05 - 9s/epoch - 21ms/step
# Epoch 57/500
# 417/417 - 9s - loss: 1.0050e-04 - 9s/epoch - 21ms/step
# Epoch 58/500
# 417/417 - 9s - loss: 8.9906e-05 - 9s/epoch - 21ms/step
# Epoch 59/500
# 417/417 - 9s - loss: 9.8701e-05 - 9s/epoch - 21ms/step
# Epoch 60/500
# 417/417 - 9s - loss: 8.9185e-05 - 9s/epoch - 22ms/step
# Epoch 61/500
# 417/417 - 9s - loss: 8.6143e-05 - 9s/epoch - 22ms/step
# Epoch 62/500
# 417/417 - 9s - loss: 8.5499e-05 - 9s/epoch - 21ms/step
# Epoch 63/500
# 417/417 - 9s - loss: 9.0238e-05 - 9s/epoch - 22ms/step
# Epoch 64/500
# 417/417 - 9s - loss: 8.1128e-05 - 9s/epoch - 21ms/step
# Epoch 65/500
# 417/417 - 9s - loss: 7.8030e-05 - 9s/epoch - 21ms/step
# Epoch 66/500
# 417/417 - 9s - loss: 7.6879e-05 - 9s/epoch - 22ms/step
# Epoch 67/500
# 417/417 - 9s - loss: 8.1858e-05 - 9s/epoch - 21ms/step
# Epoch 68/500
# 417/417 - 9s - loss: 7.2137e-05 - 9s/epoch - 21ms/step
# Epoch 69/500
# Epoch 375/500
# 417/417 - 10s - loss: 2.9859e-05 - 10s/epoch - 23ms/step
# Epoch 376/500
# 417/417 - 10s - loss: 2.8548e-05 - 10s/epoch - 24ms/step
# Epoch 377/500
# 417/417 - 9s - loss: 2.7991e-05 - 9s/epoch - 22ms/step
# Epoch 378/500
# 417/417 - 9s - loss: 2.7809e-05 - 9s/epoch - 22ms/step
# Epoch 379/500
# 417/417 - 9s - loss: 2.8290e-05 - 9s/epoch - 22ms/step
# Epoch 380/500
# 417/417 - 9s - loss: 2.9079e-05 - 9s/epoch - 22ms/step
# Epoch 381/500
# 417/417 - 9s - loss: 3.6324e-05 - 9s/epoch - 22ms/step
# Epoch 382/500
# 417/417 - 10s - loss: 2.9234e-05 - 10s/epoch - 23ms/step
# Epoch 383/500
# 417/417 - 10s - loss: 2.4433e-05 - 10s/epoch - 23ms/step
# Epoch 384/500
# 417/417 - 10s - loss: 3.1279e-05 - 10s/epoch - 23ms/step
# Epoch 385/500
# 417/417 - 10s - loss: 6.7486e-05 - 10s/epoch - 23ms/step
# Epoch 386/500
# 417/417 - 10s - loss: 5.9224e-05 - 10s/epoch - 23ms/step
# Epoch 387/500
# 417/417 - 10s - loss: 4.8149e-05 - 10s/epoch - 23ms/step
# Epoch 388/500
# 417/417 - 10s - loss: 4.7298e-05 - 10s/epoch - 23ms/step
# Epoch 389/500
# 417/417 - 10s - loss: 4.1767e-05 - 10s/epoch - 23ms/step
# Epoch 390/500
# 417/417 - 10s - loss: 3.2202e-05 - 10s/epoch - 23ms/step
# Epoch 391/500
# 417/417 - 9s - loss: 2.8987e-05 - 9s/epoch - 23ms/step
# Epoch 392/500
# 417/417 - 10s - loss: 3.0620e-05 - 10s/epoch - 23ms/step
# Epoch 393/500
# 417/417 - 9s - loss: 3.1105e-05 - 9s/epoch - 23ms/step
# Epoch 394/500
# 417/417 - 9s - loss: 2.8981e-05 - 9s/epoch - 22ms/step
# Epoch 395/500
# 417/417 - 9s - loss: 3.7464e-05 - 9s/epoch - 22ms/step
# Epoch 396/500
# 417/417 - 10s - loss: 3.5611e-05 - 10s/epoch - 23ms/step
# Epoch 397/500
# 417/417 - 10s - loss: 3.5279e-05 - 10s/epoch - 23ms/step
# Epoch 398/500
# 417/417 - 9s - loss: 3.5969e-05 - 9s/epoch - 23ms/step
# Epoch 399/500
# 417/417 - 9s - loss: 3.1860e-05 - 9s/epoch - 23ms/step
# Epoch 400/500
# 417/417 - 9s - loss: 3.0252e-05 - 9s/epoch - 23ms/step
# Epoch 401/500
# 417/417 - 10s - loss: 3.0902e-05 - 10s/epoch - 23ms/step
# Epoch 402/500
# 417/417 - 9s - loss: 2.8563e-05 - 9s/epoch - 23ms/step
# Epoch 403/500
# 417/417 - 10s - loss: 2.7261e-05 - 10s/epoch - 23ms/step
# Epoch 404/500
# 417/417 - 9s - loss: 2.8261e-05 - 9s/epoch - 23ms/step
# Epoch 405/500
# Epoch 436/500
# 417/417 - 9s - loss: 2.1937e-05 - 9s/epoch - 23ms/step
# Epoch 437/500
# 417/417 - 10s - loss: 2.1180e-05 - 10s/epoch - 23ms/step
# Epoch 438/500
# 417/417 - 10s - loss: 2.2047e-05 - 10s/epoch - 23ms/step
# Epoch 439/500
# 417/417 - 10s - loss: 2.2038e-05 - 10s/epoch - 23ms/step
# Epoch 440/500
# 417/417 - 10s - loss: 2.2417e-05 - 10s/epoch - 24ms/step
# Epoch 441/500
# 417/417 - 10s - loss: 2.1624e-05 - 10s/epoch - 23ms/step
# Epoch 442/500
# 417/417 - 9s - loss: 2.0664e-05 - 9s/epoch - 23ms/step
# Epoch 443/500
# 417/417 - 10s - loss: 2.1643e-05 - 10s/epoch - 23ms/step
# Epoch 444/500
# 417/417 - 10s - loss: 2.1614e-05 - 10s/epoch - 23ms/step
# Epoch 445/500
# 417/417 - 10s - loss: 2.1049e-05 - 10s/epoch - 24ms/step
# Epoch 446/500
# 417/417 - 10s - loss: 2.1135e-05 - 10s/epoch - 23ms/step
# Epoch 447/500
# 417/417 - 10s - loss: 2.0705e-05 - 10s/epoch - 23ms/step
# Epoch 448/500
# 417/417 - 10s - loss: 2.0602e-05 - 10s/epoch - 23ms/step
# Epoch 449/500
# 417/417 - 10s - loss: 2.1486e-05 - 10s/epoch - 23ms/step
# Epoch 450/500
# 417/417 - 10s - loss: 2.1105e-05 - 10s/epoch - 23ms/step
# Epoch 451/500
# 417/417 - 10s - loss: 1.9990e-05 - 10s/epoch - 23ms/step
# Epoch 452/500
# 417/417 - 9s - loss: 2.2228e-05 - 9s/epoch - 23ms/step
# Epoch 453/500
# 417/417 - 9s - loss: 2.0269e-05 - 9s/epoch - 23ms/step
# Epoch 454/500
# 417/417 - 10s - loss: 2.0310e-05 - 10s/epoch - 23ms/step
# Epoch 455/500
# 417/417 - 10s - loss: 2.0854e-05 - 10s/epoch - 23ms/step
# Epoch 456/500
# 417/417 - 9s - loss: 2.0228e-05 - 9s/epoch - 23ms/step
# Epoch 457/500
# 417/417 - 10s - loss: 1.9981e-05 - 10s/epoch - 23ms/step
# Epoch 458/500
# 417/417 - 10s - loss: 2.1110e-05 - 10s/epoch - 23ms/step
# Epoch 459/500
# 417/417 - 10s - loss: 1.9898e-05 - 10s/epoch - 23ms/step
# Epoch 460/500
# 417/417 - 10s - loss: 2.0985e-05 - 10s/epoch - 23ms/step
# Epoch 461/500
# 417/417 - 10s - loss: 1.9872e-05 - 10s/epoch - 23ms/step
# Epoch 462/500
# 417/417 - 10s - loss: 1.8596e-05 - 10s/epoch - 23ms/step
# Epoch 463/500
# 417/417 - 10s - loss: 2.0187e-05 - 10s/epoch - 23ms/step
# Epoch 464/500
# 417/417 - 10s - loss: 1.9599e-05 - 10s/epoch - 23ms/step
# Epoch 465/500
# 417/417 - 10s - loss: 2.0012e-05 - 10s/epoch - 23ms/step
# Epoch 466/500
# 417/417 - 10s - loss: 1.9858e-05 - 10s/epoch - 23ms/step
# Epoch 467/500
# 417/417 - 10s - loss: 1.8778e-05 - 10s/epoch - 23ms/step
# Epoch 468/500
# 417/417 - 9s - loss: 1.9550e-05 - 9s/epoch - 23ms/step
# Epoch 469/500
# 417/417 - 10s - loss: 1.9741e-05 - 10s/epoch - 23ms/step
# Epoch 470/500
# 417/417 - 10s - loss: 2.0022e-05 - 10s/epoch - 23ms/step
# Epoch 471/500
# 417/417 - 10s - loss: 1.9968e-05 - 10s/epoch - 23ms/step
# Epoch 472/500
# 417/417 - 10s - loss: 1.9860e-05 - 10s/epoch - 23ms/step
# Epoch 473/500
# 417/417 - 10s - loss: 2.3512e-05 - 10s/epoch - 23ms/step
# Epoch 474/500
# 417/417 - 9s - loss: 2.0262e-05 - 9s/epoch - 23ms/step
# Epoch 475/500
# 417/417 - 10s - loss: 1.8681e-05 - 10s/epoch - 23ms/step
# Epoch 476/500
# 417/417 - 10s - loss: 1.9712e-05 - 10s/epoch - 23ms/step
# Epoch 477/500
# 417/417 - 10s - loss: 1.8914e-05 - 10s/epoch - 23ms/step
# Epoch 478/500
# 417/417 - 10s - loss: 1.9404e-05 - 10s/epoch - 23ms/step
# Epoch 479/500
# 417/417 - 10s - loss: 2.1030e-05 - 10s/epoch - 23ms/step
# Epoch 480/500
# 417/417 - 9s - loss: 1.8735e-05 - 9s/epoch - 23ms/step
# Epoch 481/500
# 417/417 - 10s - loss: 1.9592e-05 - 10s/epoch - 23ms/step
# Epoch 482/500
# 417/417 - 10s - loss: 1.9338e-05 - 10s/epoch - 24ms/step
# Epoch 483/500
# 417/417 - 10s - loss: 1.8836e-05 - 10s/epoch - 23ms/step
# Epoch 484/500
# 417/417 - 10s - loss: 1.8337e-05 - 10s/epoch - 23ms/step
# Epoch 485/500
# 417/417 - 10s - loss: 1.9005e-05 - 10s/epoch - 23ms/step
# Epoch 486/500
# 417/417 - 10s - loss: 1.7818e-05 - 10s/epoch - 23ms/step
# Epoch 487/500
# 417/417 - 10s - loss: 1.9021e-05 - 10s/epoch - 23ms/step
# Epoch 488/500
# 417/417 - 10s - loss: 1.9447e-05 - 10s/epoch - 24ms/step
# Epoch 489/500
# 417/417 - 10s - loss: 1.8216e-05 - 10s/epoch - 24ms/step
# Epoch 490/500
# 417/417 - 10s - loss: 1.8268e-05 - 10s/epoch - 24ms/step
# Epoch 491/500
# 417/417 - 10s - loss: 1.8195e-05 - 10s/epoch - 24ms/step
# Epoch 492/500
# 417/417 - 10s - loss: 1.7893e-05 - 10s/epoch - 24ms/step
# Epoch 493/500
# 417/417 - 10s - loss: 1.9496e-05 - 10s/epoch - 24ms/step
# Epoch 494/500
# 417/417 - 10s - loss: 2.0860e-05 - 10s/epoch - 23ms/step
# Epoch 495/500
# 417/417 - 10s - loss: 1.9802e-05 - 10s/epoch - 23ms/step
# Epoch 496/500
# 417/417 - 10s - loss: 1.8391e-05 - 10s/epoch - 24ms/step
# Epoch 497/500
# 417/417 - 10s - loss: 2.0133e-05 - 10s/epoch - 24ms/step
# Epoch 498/500
# 417/417 - 10s - loss: 1.9434e-05 - 10s/epoch - 24ms/step
# Epoch 499/500
# 417/417 - 10s - loss: 1.8589e-05 - 10s/epoch - 24ms/step
# Epoch 500/500
# 417/417 - 10s - loss: 1.9092e-05 - 10s/epoch - 23ms/step

# %%
model.save('./NN_FULL__MULTIVARIATE_model')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./NN_FULL__MULTIVARIATE_model\assets
# INFO:tensorflow:Assets written to: ./NN_FULL__MULTIVARIATE_model\assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x00000115BC3DCFD0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x00000115953A6BE0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
# test data 
test_data = SNP_price[train_size - time_step:, :]
test_data_mul = SNP_attributes[train_size - time_step:, :]
test_data_mul_full = SNP_attributes[:, :]
# test_data_mul = np.array(test_data_mul)
X_test = []
X_test_mul = []
X_test_mul_full = []
y_test = SNP_price[train_size:, :]

for i in range(time_step, len(test_data)):
    X_test.append(test_data[i-time_step:i,0])

for i in range(time_step, len(test_data_mul)):
    X_test_mul.append(test_data_mul[i-time_step:i,0:test_data_mul.shape[1]])

for i in range(time_step, len(test_data_mul_full)):
    X_test_mul_full.append(test_data_mul_full[i-time_step:i,0:test_data_mul_full.shape[1]])


X_test, X_test_mul, X_test_mul_full = np.array(X_test), np.array(X_test_mul), np.array(X_test_mul_full)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
X_test_mul = np.reshape(X_test_mul, (X_test_mul.shape[0], X_test_mul.shape[1], X_test_mul.shape[2]))
X_test_mul_full = np.reshape(X_test_mul_full, (X_test_mul_full.shape[0], X_test_mul_full.shape[1], X_test_mul_full.shape[2]))

# %%
# predicted_price = model.predict(X_test)
predicted_price_mul = model.predict(X_test_mul)
# predicted_price = Price_scaler.inverse_transform(predicted_price)
predicted_price_mul = np.repeat(predicted_price_mul,X_test_mul.shape[2],axis=-1)
predicted_price_mul = scaler.inverse_transform(predicted_price_mul)[:,0]

predict_full = model.predict(X_test_mul_full)
predict_full = np.repeat(predict_full,X_test_mul_full.shape[2], axis=-1)
predict_full = scaler.inverse_transform(predict_full)[:,0]
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16396/3510528247.py in <module>
#       1 # predicted_price = model.predict(X_test)
# ----> 2 predicted_price_mul = model.predict(X_test_mul)
#       3 # predicted_price = Price_scaler.inverse_transform(predicted_price)
#       4 predicted_price_mul = np.repeat(predicted_price_mul,X_test_mul.shape[2],axis=-1)
#       5 predicted_price_mul = scaler.inverse_transform(predicted_price_mul)[:,0]
#
# c:\Users\singh\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# c:\Users\singh\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# InvalidArgumentError: Graph execution error:
#
# Specified a list with shape [?,1] from a tensor with shape [32,5]
# 	 [[{{node TensorArrayUnstack/TensorListFromTensor}}]]
# 	 [[sequential_1/lstm/PartitionedCall]] [Op:__inference_predict_function_645893]

# %%
plt.figure(figsize=(20,10))
training = SNP[:]
# valid = SNP[train_size:]
# valid['pred'] = predicted_price_mul
projection = predict_full

#plot
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.plot(training["Close"], label = 'Actual closing price')
# plt.plot(valid[['Closing Price', 'pred']])
plt.plot(projection, label = 'projected closing price')
plt.legend()
plt.show()

# %%
import math
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import classification_report
# from sklearn.metrics import accuracy_score, precision_score, recall_score
import tensorflow as tf
from keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Preprocessing

# %%
# Hyperparameters

# y column normalize scaler
normalizer_constant = 2

# time series step size
time_step = 45

# NN parameters
learning_rate = 0.1
num_epoch = 500
NN_layer_dimension = [100,100]
train_size = 568 # 80% of the data

# %%
# SNP = pd.read_csv('./SP500.csv')
SNP = pd.read_csv('./SPX_500_Data.csv')

# get all attributes
SNP_attributes = SNP.iloc[:,1:7]
# get last column (y)
# SNP_price = SNP.iloc[:,4:]
SNP_price = SNP['Close']
SNP_price = np.array(SNP_price)
SNP_price = np.reshape(SNP_price, (-1,1))

# normalize the data using MinMax scaller
scaler = MinMaxScaler()
scaler.fit(SNP_attributes)
SNP_attributes = scaler.transform(SNP_attributes)

Price_scaler = MinMaxScaler()
Price_scaler.fit(SNP_price)
SNP_price = Price_scaler.transform(SNP_price)


# scale data to [0,1]
# SNP_price = (SNP_price-SNP_price.min())/((SNP_price.max()*normalizer_constant)-SNP_price.min())

train_data = SNP_price[0:train_size, :]
train_data_mul = SNP_attributes[:, :]
# train_data_mul = np.array(train_data_mul)

# univariate
def create_train_data(data):
    x = []
    y = []
    for i in range(time_step, len(data)):
        x.append(data[i-time_step:i,0])
        y.append(data[i,0])
    return x, y

# multivariate
def create_train_data_mul(data):
    x = []
    y = []
    for i in range(time_step, len(data)):
        x.append(data[i-time_step:i, 0:data.shape[1]])
        y.append(data[i:i+1,0])
    return x, y

X_train, y_train = create_train_data_mul(train_data_mul)

# %%
# Reshaping 
X_train, y_train = np.array(X_train), np.array(y_train)
# X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
# NN 
def create_model(units=[12,3], learning_rate=0.3):
    model = tf.keras.models.Sequential()
    # LSTM RNN model
    model.add(LSTM(units=64,return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Dropout(0.2))
    model.add(LSTM(units=64,return_sequences=False))
    model.add(Dropout(0.2))
    model.add(Dense(32,activation='tanh'))
    model.add(Dense(1))

    # opt = tf.keras.optimizers.SGD(learning_rate=0.1,momentum=0.9)
    model.compile(optimizer='adam',loss='mean_squared_error')

    return model

model = create_model(units=NN_layer_dimension, learning_rate=learning_rate)

# %%
# Train
model.fit(X_train, y_train, epochs=num_epoch, batch_size=36, verbose=2)
# Out:
# Epoch 1/500
# 417/417 - 10s - loss: 0.0012 - 10s/epoch - 25ms/step
# Epoch 2/500
# 417/417 - 9s - loss: 3.5133e-04 - 9s/epoch - 21ms/step
# Epoch 3/500
# 417/417 - 9s - loss: 3.4654e-04 - 9s/epoch - 21ms/step
# Epoch 4/500
# 417/417 - 9s - loss: 2.8298e-04 - 9s/epoch - 21ms/step
# Epoch 5/500
# 417/417 - 8s - loss: 2.8211e-04 - 8s/epoch - 20ms/step
# Epoch 6/500
# 417/417 - 9s - loss: 3.0218e-04 - 9s/epoch - 21ms/step
# Epoch 7/500
# 417/417 - 9s - loss: 3.0285e-04 - 9s/epoch - 21ms/step
# Epoch 8/500
# 417/417 - 8s - loss: 3.7768e-04 - 8s/epoch - 20ms/step
# Epoch 9/500
# 417/417 - 8s - loss: 2.7712e-04 - 8s/epoch - 20ms/step
# Epoch 10/500
# 417/417 - 8s - loss: 3.0319e-04 - 8s/epoch - 20ms/step
# Epoch 11/500
# 417/417 - 8s - loss: 2.7040e-04 - 8s/epoch - 20ms/step
# Epoch 12/500
# 417/417 - 8s - loss: 2.7518e-04 - 8s/epoch - 20ms/step
# Epoch 13/500
# 417/417 - 8s - loss: 2.8172e-04 - 8s/epoch - 20ms/step
# Epoch 14/500
# 417/417 - 9s - loss: 2.7096e-04 - 9s/epoch - 20ms/step
# Epoch 15/500
# 417/417 - 9s - loss: 2.7039e-04 - 9s/epoch - 21ms/step
# Epoch 16/500
# 417/417 - 8s - loss: 2.7573e-04 - 8s/epoch - 20ms/step
# Epoch 17/500
# 417/417 - 8s - loss: 2.6188e-04 - 8s/epoch - 20ms/step
# Epoch 18/500
# 417/417 - 8s - loss: 2.4827e-04 - 8s/epoch - 20ms/step
# Epoch 19/500
# 417/417 - 8s - loss: 2.5094e-04 - 8s/epoch - 20ms/step
# Epoch 20/500
# 417/417 - 8s - loss: 2.3371e-04 - 8s/epoch - 20ms/step
# Epoch 21/500
# 417/417 - 8s - loss: 2.3031e-04 - 8s/epoch - 20ms/step
# Epoch 22/500
# 417/417 - 8s - loss: 2.4799e-04 - 8s/epoch - 20ms/step
# Epoch 23/500
# 417/417 - 8s - loss: 2.1337e-04 - 8s/epoch - 20ms/step
# Epoch 24/500
# 417/417 - 8s - loss: 2.0542e-04 - 8s/epoch - 20ms/step
# Epoch 25/500
# 417/417 - 8s - loss: 2.1290e-04 - 8s/epoch - 20ms/step
# Epoch 26/500
# 417/417 - 8s - loss: 2.0422e-04 - 8s/epoch - 20ms/step
# Epoch 27/500
# 417/417 - 8s - loss: 1.8447e-04 - 8s/epoch - 20ms/step
# Epoch 28/500
# 417/417 - 8s - loss: 1.8193e-04 - 8s/epoch - 20ms/step
# Epoch 29/500
# 417/417 - 8s - loss: 2.0851e-04 - 8s/epoch - 19ms/step
# Epoch 30/500
# 417/417 - 8s - loss: 1.5711e-04 - 8s/epoch - 20ms/step
# Epoch 31/500
# 417/417 - 8s - loss: 1.5947e-04 - 8s/epoch - 20ms/step
# Epoch 32/500
# 417/417 - 9s - loss: 1.5824e-04 - 9s/epoch - 22ms/step
# Epoch 33/500
# 417/417 - 9s - loss: 1.5172e-04 - 9s/epoch - 21ms/step
# Epoch 34/500
# 417/417 - 9s - loss: 1.4118e-04 - 9s/epoch - 21ms/step
# Epoch 35/500
# 417/417 - 9s - loss: 1.6010e-04 - 9s/epoch - 20ms/step
# Epoch 36/500
# 417/417 - 8s - loss: 1.3860e-04 - 8s/epoch - 20ms/step
# Epoch 37/500
# 417/417 - 8s - loss: 1.4257e-04 - 8s/epoch - 20ms/step
# Epoch 38/500
# 417/417 - 9s - loss: 1.3406e-04 - 9s/epoch - 20ms/step
# Epoch 39/500
# 417/417 - 8s - loss: 1.3923e-04 - 8s/epoch - 20ms/step
# Epoch 40/500
# 417/417 - 8s - loss: 1.3344e-04 - 8s/epoch - 20ms/step
# Epoch 41/500
# 417/417 - 8s - loss: 1.2102e-04 - 8s/epoch - 20ms/step
# Epoch 42/500
# 417/417 - 8s - loss: 1.1949e-04 - 8s/epoch - 20ms/step
# Epoch 43/500
# 417/417 - 8s - loss: 1.0913e-04 - 8s/epoch - 19ms/step
# Epoch 44/500
# 417/417 - 8s - loss: 1.0863e-04 - 8s/epoch - 20ms/step
# Epoch 45/500
# 417/417 - 8s - loss: 1.1196e-04 - 8s/epoch - 20ms/step
# Epoch 46/500
# 417/417 - 8s - loss: 1.0783e-04 - 8s/epoch - 20ms/step
# Epoch 47/500
# 417/417 - 8s - loss: 1.0695e-04 - 8s/epoch - 20ms/step
# Epoch 48/500
# 417/417 - 8s - loss: 1.0823e-04 - 8s/epoch - 20ms/step
# Epoch 49/500
# 417/417 - 8s - loss: 1.0362e-04 - 8s/epoch - 20ms/step
# Epoch 50/500
# 417/417 - 9s - loss: 1.0262e-04 - 9s/epoch - 21ms/step
# Epoch 51/500
# 417/417 - 9s - loss: 9.6654e-05 - 9s/epoch - 20ms/step
# Epoch 52/500
# 417/417 - 8s - loss: 9.3271e-05 - 8s/epoch - 20ms/step
# Epoch 53/500
# 417/417 - 8s - loss: 9.5464e-05 - 8s/epoch - 20ms/step
# Epoch 54/500
# 417/417 - 8s - loss: 8.7315e-05 - 8s/epoch - 19ms/step
# Epoch 55/500
# 417/417 - 8s - loss: 9.0264e-05 - 8s/epoch - 19ms/step
# Epoch 56/500
# 417/417 - 8s - loss: 9.3174e-05 - 8s/epoch - 20ms/step
# Epoch 57/500
# 417/417 - 8s - loss: 8.7309e-05 - 8s/epoch - 20ms/step
# Epoch 58/500
# 417/417 - 8s - loss: 8.0749e-05 - 8s/epoch - 19ms/step
# Epoch 59/500
# 417/417 - 8s - loss: 8.7132e-05 - 8s/epoch - 20ms/step
# Epoch 60/500
# 417/417 - 8s - loss: 7.8488e-05 - 8s/epoch - 20ms/step
# Epoch 61/500
# 417/417 - 8s - loss: 7.8359e-05 - 8s/epoch - 20ms/step
# Epoch 62/500
# 417/417 - 8s - loss: 8.0657e-05 - 8s/epoch - 20ms/step
# Epoch 63/500
# 417/417 - 8s - loss: 7.3870e-05 - 8s/epoch - 19ms/step
# Epoch 64/500
# 417/417 - 8s - loss: 7.3498e-05 - 8s/epoch - 20ms/step
# Epoch 65/500
# 417/417 - 8s - loss: 7.6585e-05 - 8s/epoch - 20ms/step
# Epoch 66/500
# 417/417 - 8s - loss: 7.6400e-05 - 8s/epoch - 20ms/step
# Epoch 67/500
# 417/417 - 9s - loss: 7.4063e-05 - 9s/epoch - 20ms/step
# Epoch 68/500
# 417/417 - 8s - loss: 6.8359e-05 - 8s/epoch - 20ms/step
# Epoch 69/500
# 417/417 - 8s - loss: 6.7660e-05 - 8s/epoch - 20ms/step
# Epoch 70/500
# 417/417 - 8s - loss: 6.4477e-05 - 8s/epoch - 20ms/step
# Epoch 71/500
# 417/417 - 8s - loss: 7.4979e-05 - 8s/epoch - 20ms/step
# Epoch 72/500
# 417/417 - 8s - loss: 6.2440e-05 - 8s/epoch - 20ms/step
# Epoch 73/500
# 417/417 - 8s - loss: 5.8654e-05 - 8s/epoch - 20ms/step
# Epoch 74/500
# 417/417 - 9s - loss: 6.7827e-05 - 9s/epoch - 20ms/step
# Epoch 75/500
# 417/417 - 9s - loss: 6.4894e-05 - 9s/epoch - 20ms/step
# Epoch 76/500
# 417/417 - 8s - loss: 6.1330e-05 - 8s/epoch - 19ms/step
# Epoch 77/500
# 417/417 - 8s - loss: 6.1558e-05 - 8s/epoch - 19ms/step
# Epoch 78/500
# 417/417 - 8s - loss: 6.0595e-05 - 8s/epoch - 20ms/step
# Epoch 79/500
# 417/417 - 8s - loss: 5.6098e-05 - 8s/epoch - 20ms/step
# Epoch 80/500
# 417/417 - 8s - loss: 5.2424e-05 - 8s/epoch - 19ms/step
# Epoch 81/500
# 417/417 - 8s - loss: 5.4073e-05 - 8s/epoch - 19ms/step
# Epoch 82/500
# 417/417 - 8s - loss: 5.2439e-05 - 8s/epoch - 19ms/step
# Epoch 83/500
# 417/417 - 8s - loss: 5.5797e-05 - 8s/epoch - 19ms/step
# Epoch 84/500
# 417/417 - 8s - loss: 5.1830e-05 - 8s/epoch - 19ms/step
# Epoch 85/500
# 417/417 - 8s - loss: 4.8258e-05 - 8s/epoch - 19ms/step
# Epoch 86/500
# 417/417 - 8s - loss: 4.9246e-05 - 8s/epoch - 19ms/step
# Epoch 87/500
# 417/417 - 8s - loss: 5.3637e-05 - 8s/epoch - 19ms/step
# Epoch 88/500
# 417/417 - 8s - loss: 4.8298e-05 - 8s/epoch - 19ms/step
# Epoch 89/500
# 417/417 - 8s - loss: 4.7165e-05 - 8s/epoch - 19ms/step
# Epoch 90/500
# 417/417 - 8s - loss: 4.2600e-05 - 8s/epoch - 19ms/step
# Epoch 91/500
# 417/417 - 8s - loss: 4.9352e-05 - 8s/epoch - 19ms/step
# Epoch 92/500
# 417/417 - 8s - loss: 5.1189e-05 - 8s/epoch - 19ms/step
# Epoch 93/500
# 417/417 - 8s - loss: 4.4334e-05 - 8s/epoch - 20ms/step
# Epoch 94/500
# 417/417 - 8s - loss: 4.4347e-05 - 8s/epoch - 20ms/step
# Epoch 95/500
# 417/417 - 8s - loss: 4.2376e-05 - 8s/epoch - 20ms/step
# Epoch 96/500
# 417/417 - 8s - loss: 4.6445e-05 - 8s/epoch - 19ms/step
# Epoch 97/500
# 417/417 - 8s - loss: 4.2175e-05 - 8s/epoch - 19ms/step
# Epoch 98/500
# 417/417 - 8s - loss: 4.3524e-05 - 8s/epoch - 19ms/step
# Epoch 99/500
# 417/417 - 8s - loss: 4.3827e-05 - 8s/epoch - 19ms/step
# Epoch 100/500
# 417/417 - 9s - loss: 4.8025e-05 - 9s/epoch - 21ms/step
# Epoch 101/500
# 417/417 - 8s - loss: 3.9341e-05 - 8s/epoch - 20ms/step
# Epoch 102/500
# 417/417 - 9s - loss: 4.2987e-05 - 9s/epoch - 20ms/step
# Epoch 103/500
# 417/417 - 8s - loss: 3.9974e-05 - 8s/epoch - 20ms/step
# Epoch 104/500
# 417/417 - 9s - loss: 4.0206e-05 - 9s/epoch - 21ms/step
# Epoch 105/500
# 417/417 - 9s - loss: 3.9763e-05 - 9s/epoch - 21ms/step
# Epoch 106/500
# 417/417 - 9s - loss: 3.9893e-05 - 9s/epoch - 21ms/step
# Epoch 107/500
# 417/417 - 8s - loss: 3.6162e-05 - 8s/epoch - 20ms/step
# Epoch 108/500
# 417/417 - 8s - loss: 3.6220e-05 - 8s/epoch - 20ms/step
# Epoch 109/500
# 417/417 - 8s - loss: 3.6769e-05 - 8s/epoch - 20ms/step
# Epoch 110/500
# 417/417 - 8s - loss: 3.7795e-05 - 8s/epoch - 20ms/step
# Epoch 111/500
# 417/417 - 9s - loss: 3.7883e-05 - 9s/epoch - 21ms/step
# Epoch 112/500
# 417/417 - 8s - loss: 3.6348e-05 - 8s/epoch - 20ms/step
# Epoch 113/500
# 417/417 - 9s - loss: 3.6014e-05 - 9s/epoch - 21ms/step
# Epoch 114/500
# 417/417 - 8s - loss: 3.6069e-05 - 8s/epoch - 20ms/step
# Epoch 115/500
# 417/417 - 8s - loss: 3.7058e-05 - 8s/epoch - 20ms/step
# Epoch 116/500
# 417/417 - 8s - loss: 3.7327e-05 - 8s/epoch - 20ms/step
# Epoch 117/500
# 417/417 - 9s - loss: 3.2671e-05 - 9s/epoch - 20ms/step
# Epoch 118/500
# 417/417 - 9s - loss: 3.1086e-05 - 9s/epoch - 21ms/step
# Epoch 119/500
# 417/417 - 9s - loss: 3.2142e-05 - 9s/epoch - 21ms/step
# Epoch 120/500
# 417/417 - 9s - loss: 3.3652e-05 - 9s/epoch - 21ms/step
# Epoch 121/500
# 417/417 - 9s - loss: 3.6709e-05 - 9s/epoch - 20ms/step
# Epoch 122/500
# 417/417 - 8s - loss: 3.3124e-05 - 8s/epoch - 20ms/step
# Epoch 123/500
# 417/417 - 8s - loss: 3.3068e-05 - 8s/epoch - 20ms/step
# Epoch 124/500
# 417/417 - 9s - loss: 3.0888e-05 - 9s/epoch - 20ms/step
# Epoch 125/500
# 417/417 - 8s - loss: 3.3203e-05 - 8s/epoch - 20ms/step
# Epoch 126/500
# 417/417 - 9s - loss: 3.2096e-05 - 9s/epoch - 20ms/step
# Epoch 127/500
# 417/417 - 9s - loss: 2.9971e-05 - 9s/epoch - 21ms/step
# Epoch 128/500
# 417/417 - 9s - loss: 3.0047e-05 - 9s/epoch - 21ms/step
# Epoch 129/500
# 417/417 - 9s - loss: 3.3912e-05 - 9s/epoch - 21ms/step
# Epoch 130/500
# 417/417 - 8s - loss: 3.0252e-05 - 8s/epoch - 20ms/step
# Epoch 131/500
# 417/417 - 9s - loss: 3.0017e-05 - 9s/epoch - 21ms/step
# Epoch 132/500
# 417/417 - 8s - loss: 3.1706e-05 - 8s/epoch - 20ms/step
# Epoch 133/500
# 417/417 - 8s - loss: 2.9254e-05 - 8s/epoch - 20ms/step
# Epoch 134/500
# 417/417 - 8s - loss: 2.9329e-05 - 8s/epoch - 20ms/step
# Epoch 135/500
# 417/417 - 8s - loss: 2.8246e-05 - 8s/epoch - 20ms/step
# Epoch 136/500
# 417/417 - 9s - loss: 2.9932e-05 - 9s/epoch - 20ms/step
# Epoch 137/500
# 417/417 - 8s - loss: 2.8833e-05 - 8s/epoch - 20ms/step
# Epoch 138/500
# 417/417 - 9s - loss: 5.3012e-05 - 9s/epoch - 21ms/step
# Epoch 171/500
# 417/417 - 9s - loss: 4.3771e-05 - 9s/epoch - 21ms/step
# Epoch 172/500
# 417/417 - 9s - loss: 4.0417e-05 - 9s/epoch - 21ms/step
# Epoch 173/500
# 417/417 - 8s - loss: 4.1749e-05 - 8s/epoch - 20ms/step
# Epoch 174/500
# 417/417 - 8s - loss: 3.9799e-05 - 8s/epoch - 19ms/step
# Epoch 175/500
# 417/417 - 8s - loss: 3.5823e-05 - 8s/epoch - 20ms/step
# Epoch 176/500
# 417/417 - 8s - loss: 3.4783e-05 - 8s/epoch - 20ms/step
# Epoch 177/500
# 417/417 - 9s - loss: 3.2396e-05 - 9s/epoch - 21ms/step
# Epoch 178/500
# 417/417 - 9s - loss: 3.6596e-05 - 9s/epoch - 21ms/step
# Epoch 179/500
# 417/417 - 8s - loss: 3.1438e-05 - 8s/epoch - 20ms/step
# Epoch 180/500
# 417/417 - 8s - loss: 3.8551e-05 - 8s/epoch - 19ms/step
# Epoch 181/500
# 417/417 - 8s - loss: 3.3707e-05 - 8s/epoch - 20ms/step
# Epoch 182/500
# 417/417 - 8s - loss: 3.2337e-05 - 8s/epoch - 20ms/step
# Epoch 183/500
# 417/417 - 8s - loss: 2.9628e-05 - 8s/epoch - 20ms/step
# Epoch 184/500
# 417/417 - 8s - loss: 3.1420e-05 - 8s/epoch - 20ms/step
# Epoch 185/500
# 417/417 - 9s - loss: 2.9448e-05 - 9s/epoch - 21ms/step
# Epoch 186/500
# 417/417 - 9s - loss: 3.1391e-05 - 9s/epoch - 21ms/step
# Epoch 187/500
# 417/417 - 8s - loss: 2.7920e-05 - 8s/epoch - 20ms/step
# Epoch 188/500
# 417/417 - 8s - loss: 2.8966e-05 - 8s/epoch - 20ms/step
# Epoch 189/500
# 417/417 - 9s - loss: 2.8647e-05 - 9s/epoch - 21ms/step
# Epoch 190/500
# 417/417 - 8s - loss: 2.9297e-05 - 8s/epoch - 20ms/step
# Epoch 191/500
# 417/417 - 8s - loss: 2.5768e-05 - 8s/epoch - 20ms/step
# Epoch 192/500
# 417/417 - 8s - loss: 2.6594e-05 - 8s/epoch - 20ms/step
# Epoch 193/500
# 417/417 - 8s - loss: 2.7857e-05 - 8s/epoch - 20ms/step
# Epoch 194/500
# 417/417 - 8s - loss: 2.5788e-05 - 8s/epoch - 20ms/step
# Epoch 195/500
# 417/417 - 8s - loss: 2.4941e-05 - 8s/epoch - 20ms/step
# Epoch 196/500
# 417/417 - 8s - loss: 2.5072e-05 - 8s/epoch - 20ms/step
# Epoch 197/500
# 417/417 - 8s - loss: 2.4608e-05 - 8s/epoch - 20ms/step
# Epoch 198/500
# 417/417 - 9s - loss: 2.5482e-05 - 9s/epoch - 21ms/step
# Epoch 199/500
# 417/417 - 8s - loss: 2.9936e-05 - 8s/epoch - 20ms/step
# Epoch 200/500
# 417/417 - 8s - loss: 2.3987e-05 - 8s/epoch - 20ms/step
# Epoch 201/500
# 417/417 - 9s - loss: 2.5637e-05 - 9s/epoch - 21ms/step
# Epoch 393/500
# 417/417 - 9s - loss: 1.2554e-05 - 9s/epoch - 21ms/step
# Epoch 394/500
# 417/417 - 9s - loss: 1.0479e-05 - 9s/epoch - 22ms/step
# Epoch 395/500
# 417/417 - 9s - loss: 1.1900e-05 - 9s/epoch - 22ms/step
# Epoch 396/500
# 417/417 - 9s - loss: 1.1140e-05 - 9s/epoch - 21ms/step
# Epoch 397/500
# 417/417 - 9s - loss: 1.1522e-05 - 9s/epoch - 21ms/step
# Epoch 398/500
# 417/417 - 9s - loss: 1.0780e-05 - 9s/epoch - 21ms/step
# Epoch 399/500
# 417/417 - 9s - loss: 1.1439e-05 - 9s/epoch - 21ms/step
# Epoch 400/500
# 417/417 - 9s - loss: 1.1214e-05 - 9s/epoch - 21ms/step
# Epoch 401/500
# 417/417 - 9s - loss: 1.0999e-05 - 9s/epoch - 21ms/step
# Epoch 402/500
# 417/417 - 9s - loss: 1.1424e-05 - 9s/epoch - 21ms/step
# Epoch 403/500
# 417/417 - 9s - loss: 1.1359e-05 - 9s/epoch - 21ms/step
# Epoch 404/500
# 417/417 - 9s - loss: 1.1552e-05 - 9s/epoch - 21ms/step
# Epoch 405/500
# 417/417 - 9s - loss: 1.0365e-05 - 9s/epoch - 22ms/step
# Epoch 406/500
# 417/417 - 9s - loss: 1.1137e-05 - 9s/epoch - 21ms/step
# Epoch 407/500
# 417/417 - 9s - loss: 1.0063e-05 - 9s/epoch - 21ms/step
# Epoch 408/500
# 417/417 - 9s - loss: 1.1880e-05 - 9s/epoch - 22ms/step
# Epoch 409/500
# 417/417 - 9s - loss: 1.0706e-05 - 9s/epoch - 21ms/step
# Epoch 410/500
# 417/417 - 9s - loss: 1.1093e-05 - 9s/epoch - 21ms/step
# Epoch 411/500
# 417/417 - 9s - loss: 1.0931e-05 - 9s/epoch - 21ms/step
# Epoch 412/500
# 417/417 - 9s - loss: 1.0605e-05 - 9s/epoch - 21ms/step
# Epoch 413/500
# 417/417 - 9s - loss: 1.1095e-05 - 9s/epoch - 21ms/step
# Epoch 414/500
# 417/417 - 9s - loss: 1.0985e-05 - 9s/epoch - 22ms/step
# Epoch 415/500
# 417/417 - 9s - loss: 1.2343e-05 - 9s/epoch - 22ms/step
# Epoch 416/500
# 417/417 - 9s - loss: 1.0776e-05 - 9s/epoch - 22ms/step
# Epoch 417/500
# 417/417 - 9s - loss: 1.0886e-05 - 9s/epoch - 21ms/step
# Epoch 418/500
# 417/417 - 9s - loss: 1.1834e-05 - 9s/epoch - 21ms/step
# Epoch 419/500
# 417/417 - 9s - loss: 1.0505e-05 - 9s/epoch - 21ms/step
# Epoch 420/500
# 417/417 - 9s - loss: 1.0523e-05 - 9s/epoch - 21ms/step
# Epoch 421/500
# 417/417 - 9s - loss: 1.0558e-05 - 9s/epoch - 21ms/step
# Epoch 422/500
# 417/417 - 9s - loss: 1.0174e-05 - 9s/epoch - 22ms/step
# Epoch 423/500
# 417/417 - 9s - loss: 1.1721e-05 - 9s/epoch - 21ms/step
# Epoch 424/500
# 417/417 - 9s - loss: 1.0845e-05 - 9s/epoch - 21ms/step
# Epoch 425/500
# 417/417 - 9s - loss: 1.0592e-05 - 9s/epoch - 22ms/step
# Epoch 426/500
# 417/417 - 9s - loss: 1.0883e-05 - 9s/epoch - 22ms/step
# Epoch 427/500
# 417/417 - 9s - loss: 1.1372e-05 - 9s/epoch - 22ms/step
# Epoch 428/500
# 417/417 - 9s - loss: 1.0876e-05 - 9s/epoch - 21ms/step
# Epoch 429/500
# 417/417 - 9s - loss: 1.0847e-05 - 9s/epoch - 22ms/step
# Epoch 430/500
# 417/417 - 9s - loss: 1.1782e-05 - 9s/epoch - 22ms/step
# Epoch 431/500
# 417/417 - 9s - loss: 1.0856e-05 - 9s/epoch - 21ms/step
# Epoch 432/500
# 417/417 - 9s - loss: 1.0527e-05 - 9s/epoch - 21ms/step
# Epoch 433/500
# 417/417 - 9s - loss: 1.0105e-05 - 9s/epoch - 21ms/step
# Epoch 434/500
# 417/417 - 9s - loss: 1.0483e-05 - 9s/epoch - 21ms/step
# Epoch 435/500
# 417/417 - 9s - loss: 1.0319e-05 - 9s/epoch - 21ms/step
# Epoch 436/500
# 417/417 - 9s - loss: 1.0192e-05 - 9s/epoch - 21ms/step
# Epoch 437/500
# 417/417 - 9s - loss: 1.0927e-05 - 9s/epoch - 22ms/step
# Epoch 438/500
# 417/417 - 9s - loss: 1.0955e-05 - 9s/epoch - 21ms/step
# Epoch 439/500
# 417/417 - 9s - loss: 1.0661e-05 - 9s/epoch - 22ms/step
# Epoch 440/500
# 417/417 - 9s - loss: 1.3534e-05 - 9s/epoch - 21ms/step
# Epoch 441/500
# 417/417 - 9s - loss: 1.0337e-05 - 9s/epoch - 22ms/step
# Epoch 442/500
# 417/417 - 9s - loss: 1.0028e-05 - 9s/epoch - 22ms/step
# Epoch 443/500
# 417/417 - 9s - loss: 1.0373e-05 - 9s/epoch - 22ms/step
# Epoch 444/500
# 417/417 - 9s - loss: 1.0598e-05 - 9s/epoch - 22ms/step
# Epoch 445/500
# 417/417 - 9s - loss: 9.7639e-06 - 9s/epoch - 22ms/step
# Epoch 446/500
# 417/417 - 9s - loss: 9.7385e-06 - 9s/epoch - 22ms/step
# Epoch 447/500
# 417/417 - 9s - loss: 1.1071e-05 - 9s/epoch - 22ms/step
# Epoch 448/500
# 417/417 - 9s - loss: 1.0612e-05 - 9s/epoch - 22ms/step
# Epoch 449/500
# 417/417 - 9s - loss: 1.1442e-05 - 9s/epoch - 22ms/step
# Epoch 450/500
# 417/417 - 9s - loss: 3.0073e-05 - 9s/epoch - 22ms/step
# Epoch 451/500
# 417/417 - 9s - loss: 1.3360e-05 - 9s/epoch - 22ms/step
# Epoch 452/500
# 417/417 - 9s - loss: 1.2009e-05 - 9s/epoch - 22ms/step
# Epoch 453/500
# 417/417 - 9s - loss: 1.1478e-05 - 9s/epoch - 22ms/step
# Epoch 454/500
# 417/417 - 9s - loss: 1.0499e-05 - 9s/epoch - 22ms/step
# Epoch 455/500
# 417/417 - 9s - loss: 1.1161e-05 - 9s/epoch - 21ms/step
# Epoch 456/500
# 417/417 - 9s - loss: 1.0315e-05 - 9s/epoch - 22ms/step
# Epoch 457/500
# 417/417 - 9s - loss: 1.0695e-05 - 9s/epoch - 21ms/step
# Epoch 458/500
# 417/417 - 9s - loss: 9.6428e-06 - 9s/epoch - 22ms/step
# Epoch 459/500
# 417/417 - 9s - loss: 9.5909e-06 - 9s/epoch - 21ms/step
# Epoch 460/500
# 417/417 - 9s - loss: 2.1261e-05 - 9s/epoch - 21ms/step
# Epoch 461/500
# 417/417 - 9s - loss: 1.4530e-05 - 9s/epoch - 22ms/step
# Epoch 462/500
# 417/417 - 9s - loss: 1.2486e-05 - 9s/epoch - 21ms/step
# Epoch 463/500
# 417/417 - 9s - loss: 1.1410e-05 - 9s/epoch - 22ms/step
# Epoch 464/500
# 417/417 - 9s - loss: 1.2519e-05 - 9s/epoch - 22ms/step
# Epoch 465/500
# 417/417 - 9s - loss: 1.1889e-05 - 9s/epoch - 22ms/step
# Epoch 466/500
# 417/417 - 9s - loss: 1.1848e-05 - 9s/epoch - 22ms/step
# Epoch 467/500
# 417/417 - 9s - loss: 1.1587e-05 - 9s/epoch - 22ms/step
# Epoch 468/500
# 417/417 - 9s - loss: 1.0748e-05 - 9s/epoch - 22ms/step
# Epoch 469/500
# 417/417 - 9s - loss: 1.0374e-05 - 9s/epoch - 21ms/step
# Epoch 470/500
# 417/417 - 9s - loss: 1.1564e-05 - 9s/epoch - 22ms/step
# Epoch 471/500
# 417/417 - 9s - loss: 1.0563e-05 - 9s/epoch - 22ms/step
# Epoch 472/500
# 417/417 - 9s - loss: 1.0580e-05 - 9s/epoch - 22ms/step
# Epoch 473/500
# 417/417 - 9s - loss: 1.1122e-05 - 9s/epoch - 22ms/step
# Epoch 474/500
# 417/417 - 9s - loss: 1.0830e-05 - 9s/epoch - 22ms/step
# Epoch 475/500
# 417/417 - 9s - loss: 1.1734e-05 - 9s/epoch - 21ms/step
# Epoch 476/500
# 417/417 - 9s - loss: 1.1002e-05 - 9s/epoch - 22ms/step
# Epoch 477/500
# 417/417 - 9s - loss: 1.0363e-05 - 9s/epoch - 22ms/step
# Epoch 478/500
# 417/417 - 9s - loss: 1.1162e-05 - 9s/epoch - 22ms/step
# Epoch 479/500
# 417/417 - 9s - loss: 1.0967e-05 - 9s/epoch - 22ms/step
# Epoch 480/500
# 417/417 - 9s - loss: 9.9494e-06 - 9s/epoch - 22ms/step
# Epoch 481/500
# 417/417 - 9s - loss: 1.1089e-05 - 9s/epoch - 22ms/step
# Epoch 482/500
# 417/417 - 9s - loss: 9.7932e-06 - 9s/epoch - 22ms/step
# Epoch 483/500
# 417/417 - 9s - loss: 1.0335e-05 - 9s/epoch - 22ms/step
# Epoch 484/500
# 417/417 - 9s - loss: 1.1059e-05 - 9s/epoch - 22ms/step
# Epoch 485/500
# 417/417 - 9s - loss: 1.0592e-05 - 9s/epoch - 22ms/step
# Epoch 486/500
# 417/417 - 9s - loss: 1.0131e-05 - 9s/epoch - 22ms/step
# Epoch 487/500
# 417/417 - 9s - loss: 1.0728e-05 - 9s/epoch - 22ms/step
# Epoch 488/500
# 417/417 - 9s - loss: 9.6504e-06 - 9s/epoch - 22ms/step
# Epoch 489/500
# 417/417 - 9s - loss: 1.1269e-05 - 9s/epoch - 22ms/step
# Epoch 490/500
# 417/417 - 9s - loss: 1.1686e-05 - 9s/epoch - 22ms/step
# Epoch 491/500
# 417/417 - 9s - loss: 1.1368e-05 - 9s/epoch - 22ms/step
# Epoch 492/500
# 417/417 - 9s - loss: 1.0456e-05 - 9s/epoch - 22ms/step
# Epoch 493/500
# 417/417 - 9s - loss: 9.7803e-06 - 9s/epoch - 22ms/step
# Epoch 494/500
# 417/417 - 9s - loss: 1.1545e-05 - 9s/epoch - 22ms/step
# Epoch 495/500
# 417/417 - 9s - loss: 1.2245e-05 - 9s/epoch - 22ms/step
# Epoch 496/500
# 417/417 - 9s - loss: 1.2275e-05 - 9s/epoch - 22ms/step
# Epoch 497/500
# 417/417 - 9s - loss: 1.0546e-05 - 9s/epoch - 22ms/step
# Epoch 498/500
# 417/417 - 9s - loss: 1.0034e-05 - 9s/epoch - 22ms/step
# Epoch 499/500
# 417/417 - 9s - loss: 9.5360e-06 - 9s/epoch - 22ms/step
# Epoch 500/500
# 417/417 - 9s - loss: 1.0223e-05 - 9s/epoch - 22ms/step

# %%
model.save('./NN_model')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./NN_model\assets
# INFO:tensorflow:Assets written to: ./NN_model\assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x0000023DD28A2E50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x0000023DED7ECA30> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
# test data 
test_data = SNP_price[train_size - time_step:, :]
test_data_mul = SNP_attributes[train_size - time_step:, :]
test_data_mul_full = SNP_attributes[:, :]
# test_data_mul = np.array(test_data_mul)
X_test = []
X_test_mul = []
X_test_mul_full = []
y_test = SNP_price[train_size:, :]

for i in range(time_step, len(test_data)):
    X_test.append(test_data[i-time_step:i,0])

for i in range(time_step, len(test_data_mul)):
    X_test_mul.append(test_data_mul[i-time_step:i,0:test_data_mul.shape[1]])

for i in range(time_step, len(test_data_mul_full)):
    X_test_mul_full.append(test_data_mul_full[i-time_step:i,0:test_data_mul_full.shape[1]])


X_test, X_test_mul, X_test_mul_full = np.array(X_test), np.array(X_test_mul), np.array(X_test_mul_full)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
X_test_mul = np.reshape(X_test_mul, (X_test_mul.shape[0], X_test_mul.shape[1], X_test_mul.shape[2]))
X_test_mul_full = np.reshape(X_test_mul_full, (X_test_mul_full.shape[0], X_test_mul_full.shape[1], X_test_mul_full.shape[2]))

# %%
# predicted_price = model.predict(X_test)
predicted_price_mul = model.predict(X_test_mul)
# predicted_price = Price_scaler.inverse_transform(predicted_price)
predicted_price_mul = np.repeat(predicted_price_mul,X_test_mul.shape[2],axis=-1)
predicted_price_mul = scaler.inverse_transform(predicted_price_mul)[:,0]

predict_full = model.predict(X_test_mul_full)
predict_full = np.repeat(predict_full,X_test_mul_full.shape[2], axis=-1)
predict_full = scaler.inverse_transform(predict_full)[:,0]

# %%
plt.figure(figsize=(20,10))
training = SNP[:]
# valid = SNP[train_size:]
# valid['pred'] = predicted_price_mul
projection = predict_full

#plot
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.plot(training["Close"], label = 'Actual closing price')
# plt.plot(valid[['Closing Price', 'pred']])
plt.plot(projection, label = 'projected closing price')
plt.legend()
plt.show()

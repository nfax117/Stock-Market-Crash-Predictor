# %%
import math
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import classification_report
# from sklearn.metrics import accuracy_score, precision_score, recall_score
import tensorflow as tf
from keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Preprocessing

# %%
# Hyperparameters

# y column normalize scaler
normalizer_constant = 2

# time series step size
time_step = 14

# NN parameters
learning_rate = 0.1
num_epoch = 500
NN_layer_dimension = [100,100]
train_size = 568 # 80% of the data

# %%
# SNP = pd.read_csv('./SP500.csv')
SNP = pd.read_csv('./SPX_500_Data.csv')

# get all attributes
SNP_attributes = SNP.iloc[:,1:7]
# get last column (y)
# SNP_price = SNP.iloc[:,4:]
SNP_price = SNP['Close']
SNP_price = np.array(SNP_price)
SNP_price = np.reshape(SNP_price, (-1,1))

# normalize the data using MinMax scaller
scaler = MinMaxScaler()
scaler.fit(SNP_attributes)
SNP_attributes = scaler.transform(SNP_attributes)

Price_scaler = MinMaxScaler()
Price_scaler.fit(SNP_price)
SNP_price = Price_scaler.transform(SNP_price)


# scale data to [0,1]
# SNP_price = (SNP_price-SNP_price.min())/((SNP_price.max()*normalizer_constant)-SNP_price.min())

train_data = SNP_price[0:train_size, :]
train_data_mul = SNP_attributes[:, :]
# train_data_mul = np.array(train_data_mul)

# univariate
def create_train_data(data):
    x = []
    y = []
    for i in range(time_step, len(data)):
        x.append(data[i-time_step:i,0])
        y.append(data[i,0])
    return x, y

# multivariate
def create_train_data_mul(data):
    x = []
    y = []
    for i in range(time_step, len(data)):
        x.append(data[i-time_step:i, 0:data.shape[1]])
        y.append(data[i:i+1,0])
    return x, y

X_train, y_train = create_train_data_mul(train_data_mul)

# %%
# Reshaping 
X_train, y_train = np.array(X_train), np.array(y_train)
# X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
# NN 
def create_model(units=[12,3], learning_rate=0.3):
    model = tf.keras.models.Sequential()
    # # LSTM RNN model
    model.add(LSTM(units=128,return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
    # model.add(Dropout(0.2))
    model.add(LSTM(units=64,return_sequences=False))
    model.add(Dropout(0.2))
    model.add(Dense(32,activation='tanh'))
    model.add(Dense(1))

    # opt = tf.keras.optimizers.SGD(learning_rate=0.1,momentum=0.9)
    model.compile(optimizer='adam',loss='mean_squared_error')

    return model

model = create_model(units=NN_layer_dimension, learning_rate=learning_rate)

# %%
# Train
model.fit(X_train, y_train, epochs=num_epoch, batch_size=24, verbose=2)
# Out:
# Epoch 1/500
# 626/626 - 7s - loss: 7.9484e-04 - 7s/epoch - 11ms/step
# Epoch 2/500
# 626/626 - 5s - loss: 2.8351e-04 - 5s/epoch - 8ms/step
# Epoch 3/500
# 626/626 - 5s - loss: 3.2797e-04 - 5s/epoch - 8ms/step
# Epoch 4/500
# 626/626 - 5s - loss: 2.5366e-04 - 5s/epoch - 8ms/step
# Epoch 5/500
# 626/626 - 5s - loss: 2.3338e-04 - 5s/epoch - 9ms/step
# Epoch 6/500
# 626/626 - 5s - loss: 2.6271e-04 - 5s/epoch - 8ms/step
# Epoch 7/500
# 626/626 - 5s - loss: 2.3846e-04 - 5s/epoch - 8ms/step
# Epoch 8/500
# 626/626 - 5s - loss: 2.4667e-04 - 5s/epoch - 8ms/step
# Epoch 9/500
# 626/626 - 5s - loss: 2.2847e-04 - 5s/epoch - 8ms/step
# Epoch 10/500
# 626/626 - 5s - loss: 2.7862e-04 - 5s/epoch - 8ms/step
# Epoch 11/500
# 626/626 - 5s - loss: 2.5491e-04 - 5s/epoch - 8ms/step
# Epoch 12/500
# 626/626 - 5s - loss: 2.2510e-04 - 5s/epoch - 8ms/step
# Epoch 13/500
# 626/626 - 5s - loss: 2.2730e-04 - 5s/epoch - 8ms/step
# Epoch 14/500
# 626/626 - 5s - loss: 2.0668e-04 - 5s/epoch - 9ms/step
# Epoch 15/500
# 626/626 - 5s - loss: 2.3315e-04 - 5s/epoch - 8ms/step
# Epoch 16/500
# 626/626 - 5s - loss: 2.0300e-04 - 5s/epoch - 9ms/step
# Epoch 17/500
# 626/626 - 5s - loss: 1.9552e-04 - 5s/epoch - 8ms/step
# Epoch 18/500
# 626/626 - 5s - loss: 1.9226e-04 - 5s/epoch - 8ms/step
# Epoch 19/500
# 626/626 - 5s - loss: 1.9517e-04 - 5s/epoch - 8ms/step
# Epoch 20/500
# 626/626 - 5s - loss: 1.7987e-04 - 5s/epoch - 8ms/step
# Epoch 21/500
# 626/626 - 5s - loss: 1.9655e-04 - 5s/epoch - 8ms/step
# Epoch 22/500
# 626/626 - 5s - loss: 1.7562e-04 - 5s/epoch - 8ms/step
# Epoch 23/500
# 626/626 - 6s - loss: 1.6457e-04 - 6s/epoch - 9ms/step
# Epoch 24/500
# 626/626 - 5s - loss: 1.4779e-04 - 5s/epoch - 8ms/step
# Epoch 25/500
# 626/626 - 5s - loss: 1.6008e-04 - 5s/epoch - 9ms/step
# Epoch 26/500
# 626/626 - 5s - loss: 1.3748e-04 - 5s/epoch - 9ms/step
# Epoch 27/500
# 626/626 - 5s - loss: 1.3496e-04 - 5s/epoch - 9ms/step
# Epoch 28/500
# 626/626 - 5s - loss: 1.2905e-04 - 5s/epoch - 8ms/step
# Epoch 29/500
# 626/626 - 5s - loss: 1.1809e-04 - 5s/epoch - 8ms/step
# Epoch 30/500
# 626/626 - 5s - loss: 1.2147e-04 - 5s/epoch - 8ms/step
# Epoch 31/500
# 626/626 - 5s - loss: 1.0936e-04 - 5s/epoch - 8ms/step
# Epoch 32/500
# 626/626 - 5s - loss: 1.0688e-04 - 5s/epoch - 9ms/step
# Epoch 33/500
# 626/626 - 5s - loss: 1.0413e-04 - 5s/epoch - 8ms/step
# Epoch 34/500
# 626/626 - 5s - loss: 1.0349e-04 - 5s/epoch - 8ms/step
# Epoch 35/500
# 626/626 - 5s - loss: 9.9673e-05 - 5s/epoch - 8ms/step
# Epoch 36/500
# 626/626 - 5s - loss: 9.8871e-05 - 5s/epoch - 8ms/step
# Epoch 37/500
# 626/626 - 5s - loss: 9.3439e-05 - 5s/epoch - 9ms/step
# Epoch 38/500
# 626/626 - 5s - loss: 8.6466e-05 - 5s/epoch - 8ms/step
# Epoch 39/500
# 626/626 - 5s - loss: 8.4487e-05 - 5s/epoch - 8ms/step
# Epoch 40/500
# 626/626 - 5s - loss: 8.5075e-05 - 5s/epoch - 9ms/step
# Epoch 41/500
# 626/626 - 5s - loss: 8.7866e-05 - 5s/epoch - 8ms/step
# Epoch 42/500
# 626/626 - 5s - loss: 3.8335e-05 - 5s/epoch - 8ms/step
# Epoch 75/500
# 626/626 - 6s - loss: 3.7301e-05 - 6s/epoch - 9ms/step
# Epoch 76/500
# 626/626 - 5s - loss: 4.2079e-05 - 5s/epoch - 8ms/step
# Epoch 77/500
# 626/626 - 5s - loss: 4.1227e-05 - 5s/epoch - 8ms/step
# Epoch 78/500
# 626/626 - 5s - loss: 3.3455e-05 - 5s/epoch - 8ms/step
# Epoch 79/500
# 626/626 - 5s - loss: 3.4240e-05 - 5s/epoch - 8ms/step
# Epoch 80/500
# 626/626 - 5s - loss: 3.4755e-05 - 5s/epoch - 8ms/step
# Epoch 81/500
# 626/626 - 5s - loss: 3.3660e-05 - 5s/epoch - 8ms/step
# Epoch 82/500
# 626/626 - 5s - loss: 3.2173e-05 - 5s/epoch - 8ms/step
# Epoch 83/500
# 626/626 - 5s - loss: 3.5450e-05 - 5s/epoch - 8ms/step
# Epoch 84/500
# 626/626 - 6s - loss: 3.0886e-05 - 6s/epoch - 9ms/step
# Epoch 85/500
# 626/626 - 5s - loss: 3.0876e-05 - 5s/epoch - 9ms/step
# Epoch 86/500
# 626/626 - 6s - loss: 2.8039e-05 - 6s/epoch - 9ms/step
# Epoch 87/500
# 626/626 - 5s - loss: 3.2861e-05 - 5s/epoch - 9ms/step
# Epoch 88/500
# 626/626 - 5s - loss: 2.8252e-05 - 5s/epoch - 9ms/step
# Epoch 89/500
# 626/626 - 5s - loss: 2.8953e-05 - 5s/epoch - 8ms/step
# Epoch 90/500
# 626/626 - 5s - loss: 2.8323e-05 - 5s/epoch - 8ms/step
# Epoch 91/500
# 626/626 - 5s - loss: 2.5688e-05 - 5s/epoch - 8ms/step
# Epoch 92/500
# 626/626 - 5s - loss: 2.7791e-05 - 5s/epoch - 8ms/step
# Epoch 93/500
# 626/626 - 5s - loss: 2.5669e-05 - 5s/epoch - 9ms/step
# Epoch 94/500
# 626/626 - 5s - loss: 2.8405e-05 - 5s/epoch - 8ms/step
# Epoch 95/500
# 626/626 - 5s - loss: 2.5401e-05 - 5s/epoch - 8ms/step
# Epoch 96/500
# 626/626 - 5s - loss: 2.5805e-05 - 5s/epoch - 9ms/step
# Epoch 97/500
# 626/626 - 5s - loss: 2.4462e-05 - 5s/epoch - 8ms/step
# Epoch 98/500
# 626/626 - 5s - loss: 2.4975e-05 - 5s/epoch - 8ms/step
# Epoch 99/500
# 626/626 - 5s - loss: 2.3293e-05 - 5s/epoch - 8ms/step
# Epoch 100/500
# 626/626 - 5s - loss: 2.3537e-05 - 5s/epoch - 8ms/step
# Epoch 101/500
# 626/626 - 5s - loss: 2.3791e-05 - 5s/epoch - 8ms/step
# Epoch 102/500
# 626/626 - 5s - loss: 2.2616e-05 - 5s/epoch - 8ms/step
# Epoch 103/500
# 626/626 - 5s - loss: 2.4947e-05 - 5s/epoch - 9ms/step
# Epoch 104/500
# 626/626 - 5s - loss: 2.2195e-05 - 5s/epoch - 8ms/step
# Epoch 105/500
# 626/626 - 5s - loss: 2.2766e-05 - 5s/epoch - 8ms/step
# Epoch 106/500
# 626/626 - 5s - loss: 2.2959e-05 - 5s/epoch - 8ms/step
# Epoch 107/500
# 626/626 - 6s - loss: 2.3047e-05 - 6s/epoch - 9ms/step
# Epoch 108/500
# 626/626 - 6s - loss: 2.0494e-05 - 6s/epoch - 9ms/step
# Epoch 109/500
# 626/626 - 5s - loss: 2.2101e-05 - 5s/epoch - 9ms/step
# Epoch 110/500
# 626/626 - 5s - loss: 2.0807e-05 - 5s/epoch - 8ms/step
# Epoch 111/500
# 626/626 - 5s - loss: 2.2935e-05 - 5s/epoch - 8ms/step
# Epoch 112/500
# 626/626 - 5s - loss: 2.0805e-05 - 5s/epoch - 8ms/step
# Epoch 113/500
# 626/626 - 5s - loss: 2.5838e-05 - 5s/epoch - 9ms/step
# Epoch 114/500
# 626/626 - 5s - loss: 2.2879e-05 - 5s/epoch - 9ms/step
# Epoch 115/500
# 626/626 - 5s - loss: 2.1547e-05 - 5s/epoch - 9ms/step
# Epoch 116/500
# 626/626 - 5s - loss: 2.3209e-05 - 5s/epoch - 9ms/step
# Epoch 117/500
# 626/626 - 5s - loss: 2.1779e-05 - 5s/epoch - 9ms/step
# Epoch 118/500
# 626/626 - 6s - loss: 2.0979e-05 - 6s/epoch - 9ms/step
# Epoch 119/500
# 626/626 - 5s - loss: 1.9740e-05 - 5s/epoch - 9ms/step
# Epoch 120/500
# 626/626 - 5s - loss: 1.9386e-05 - 5s/epoch - 9ms/step
# Epoch 121/500
# 626/626 - 5s - loss: 1.9921e-05 - 5s/epoch - 9ms/step
# Epoch 122/500
# 626/626 - 5s - loss: 1.9300e-05 - 5s/epoch - 9ms/step
# Epoch 123/500
# 626/626 - 5s - loss: 2.0789e-05 - 5s/epoch - 9ms/step
# Epoch 124/500
# 626/626 - 5s - loss: 1.8965e-05 - 5s/epoch - 9ms/step
# Epoch 125/500
# 626/626 - 5s - loss: 1.8123e-05 - 5s/epoch - 9ms/step
# Epoch 126/500
# 626/626 - 5s - loss: 1.8583e-05 - 5s/epoch - 9ms/step
# Epoch 127/500
# 626/626 - 5s - loss: 1.9585e-05 - 5s/epoch - 9ms/step
# Epoch 128/500
# 626/626 - 5s - loss: 1.9950e-05 - 5s/epoch - 9ms/step
# Epoch 129/500
# 626/626 - 6s - loss: 1.8632e-05 - 6s/epoch - 9ms/step
# Epoch 130/500
# 626/626 - 5s - loss: 1.8847e-05 - 5s/epoch - 9ms/step
# Epoch 131/500
# 626/626 - 5s - loss: 1.7848e-05 - 5s/epoch - 9ms/step
# Epoch 132/500
# 626/626 - 5s - loss: 1.6669e-05 - 5s/epoch - 9ms/step
# Epoch 133/500
# 626/626 - 5s - loss: 1.9573e-05 - 5s/epoch - 9ms/step
# Epoch 134/500
# 626/626 - 5s - loss: 1.7904e-05 - 5s/epoch - 9ms/step
# Epoch 135/500
# 626/626 - 5s - loss: 1.8375e-05 - 5s/epoch - 9ms/step
# Epoch 136/500
# 626/626 - 5s - loss: 1.8550e-05 - 5s/epoch - 9ms/step
# Epoch 137/500
# 626/626 - 5s - loss: 1.7470e-05 - 5s/epoch - 9ms/step
# Epoch 138/500
# 626/626 - 5s - loss: 1.7884e-05 - 5s/epoch - 9ms/step
# Epoch 139/500
# 626/626 - 5s - loss: 1.7521e-05 - 5s/epoch - 9ms/step
# Epoch 140/500
# 626/626 - 6s - loss: 1.7205e-05 - 6s/epoch - 9ms/step
# Epoch 141/500
# 626/626 - 5s - loss: 1.6883e-05 - 5s/epoch - 9ms/step
# Epoch 142/500
# 626/626 - 5s - loss: 1.8636e-05 - 5s/epoch - 9ms/step
# Epoch 143/500
# 626/626 - 5s - loss: 1.6243e-05 - 5s/epoch - 9ms/step
# Epoch 144/500
# 626/626 - 5s - loss: 1.8706e-05 - 5s/epoch - 9ms/step
# Epoch 145/500
# 626/626 - 5s - loss: 1.7616e-05 - 5s/epoch - 9ms/step
# Epoch 146/500
# 626/626 - 5s - loss: 1.6002e-05 - 5s/epoch - 9ms/step
# Epoch 147/500
# 626/626 - 5s - loss: 1.7086e-05 - 5s/epoch - 9ms/step
# Epoch 148/500
# 626/626 - 6s - loss: 1.8376e-05 - 6s/epoch - 9ms/step
# Epoch 149/500
# 626/626 - 5s - loss: 1.7218e-05 - 5s/epoch - 9ms/step
# Epoch 150/500
# 626/626 - 5s - loss: 1.8272e-05 - 5s/epoch - 9ms/step
# Epoch 151/500
# 626/626 - 6s - loss: 1.7545e-05 - 6s/epoch - 9ms/step
# Epoch 152/500
# 626/626 - 5s - loss: 1.6895e-05 - 5s/epoch - 9ms/step
# Epoch 153/500
# 626/626 - 6s - loss: 1.6172e-05 - 6s/epoch - 9ms/step
# Epoch 154/500
# 626/626 - 6s - loss: 1.7114e-05 - 6s/epoch - 9ms/step
# Epoch 155/500
# 626/626 - 6s - loss: 1.7616e-05 - 6s/epoch - 9ms/step
# Epoch 156/500
# 626/626 - 6s - loss: 1.8192e-05 - 6s/epoch - 9ms/step
# Epoch 157/500
# 626/626 - 6s - loss: 1.5813e-05 - 6s/epoch - 9ms/step
# Epoch 158/500
# 626/626 - 6s - loss: 1.6081e-05 - 6s/epoch - 9ms/step
# Epoch 159/500
# 626/626 - 6s - loss: 1.5835e-05 - 6s/epoch - 9ms/step
# Epoch 160/500
# 626/626 - 6s - loss: 1.5868e-05 - 6s/epoch - 9ms/step
# Epoch 161/500
# 626/626 - 6s - loss: 1.5858e-05 - 6s/epoch - 9ms/step
# Epoch 162/500
# 626/626 - 6s - loss: 1.7786e-05 - 6s/epoch - 10ms/step
# Epoch 163/500
# 626/626 - 6s - loss: 1.5480e-05 - 6s/epoch - 9ms/step
# Epoch 164/500
# 626/626 - 6s - loss: 1.5782e-05 - 6s/epoch - 9ms/step
# Epoch 165/500
# 626/626 - 6s - loss: 1.5710e-05 - 6s/epoch - 9ms/step
# Epoch 166/500
# 626/626 - 6s - loss: 1.7044e-05 - 6s/epoch - 9ms/step
# Epoch 167/500
# 626/626 - 6s - loss: 1.5474e-05 - 6s/epoch - 9ms/step
# Epoch 168/500
# 626/626 - 6s - loss: 1.6095e-05 - 6s/epoch - 9ms/step
# Epoch 169/500
# 626/626 - 6s - loss: 1.5597e-05 - 6s/epoch - 10ms/step
# Epoch 170/500
# 626/626 - 6s - loss: 1.5660e-05 - 6s/epoch - 10ms/step
# Epoch 171/500
# 626/626 - 6s - loss: 1.6747e-05 - 6s/epoch - 10ms/step
# Epoch 172/500
# 626/626 - 6s - loss: 1.8500e-05 - 6s/epoch - 10ms/step
# Epoch 173/500
# 626/626 - 6s - loss: 1.6137e-05 - 6s/epoch - 9ms/step
# Epoch 174/500
# 626/626 - 6s - loss: 1.6692e-05 - 6s/epoch - 9ms/step
# Epoch 175/500
# 626/626 - 6s - loss: 1.5757e-05 - 6s/epoch - 9ms/step
# Epoch 176/500
# 626/626 - 6s - loss: 1.5032e-05 - 6s/epoch - 9ms/step
# Epoch 177/500
# 626/626 - 6s - loss: 1.5226e-05 - 6s/epoch - 9ms/step
# Epoch 178/500
# 626/626 - 6s - loss: 1.6016e-05 - 6s/epoch - 9ms/step
# Epoch 179/500
# 626/626 - 6s - loss: 1.4581e-05 - 6s/epoch - 9ms/step
# Epoch 180/500
# 626/626 - 6s - loss: 1.7048e-05 - 6s/epoch - 9ms/step
# Epoch 181/500
# 626/626 - 6s - loss: 1.6237e-05 - 6s/epoch - 9ms/step
# Epoch 182/500
# 626/626 - 6s - loss: 1.6222e-05 - 6s/epoch - 9ms/step
# Epoch 183/500
# 626/626 - 6s - loss: 1.5070e-05 - 6s/epoch - 9ms/step
# Epoch 184/500
# 626/626 - 6s - loss: 1.3950e-05 - 6s/epoch - 10ms/step
# Epoch 185/500
# 626/626 - 6s - loss: 1.5083e-05 - 6s/epoch - 10ms/step
# Epoch 186/500
# 626/626 - 6s - loss: 1.5703e-05 - 6s/epoch - 10ms/step
# Epoch 187/500
# 626/626 - 6s - loss: 1.4459e-05 - 6s/epoch - 9ms/step
# Epoch 188/500
# 626/626 - 6s - loss: 1.6323e-05 - 6s/epoch - 9ms/step
# Epoch 189/500
# 626/626 - 6s - loss: 1.5449e-05 - 6s/epoch - 10ms/step
# Epoch 190/500
# 626/626 - 6s - loss: 1.3981e-05 - 6s/epoch - 10ms/step
# Epoch 191/500
# 626/626 - 6s - loss: 1.5177e-05 - 6s/epoch - 10ms/step
# Epoch 192/500
# 626/626 - 6s - loss: 1.4623e-05 - 6s/epoch - 10ms/step
# Epoch 193/500
# 626/626 - 6s - loss: 1.5108e-05 - 6s/epoch - 10ms/step
# Epoch 194/500
# 626/626 - 6s - loss: 1.5054e-05 - 6s/epoch - 10ms/step
# Epoch 195/500
# 626/626 - 6s - loss: 1.5562e-05 - 6s/epoch - 10ms/step
# Epoch 196/500
# 626/626 - 6s - loss: 1.4396e-05 - 6s/epoch - 9ms/step
# Epoch 197/500
# 626/626 - 6s - loss: 1.4483e-05 - 6s/epoch - 9ms/step
# Epoch 198/500
# 626/626 - 6s - loss: 1.4133e-05 - 6s/epoch - 10ms/step
# Epoch 199/500
# 626/626 - 6s - loss: 1.4780e-05 - 6s/epoch - 10ms/step
# Epoch 200/500
# 626/626 - 6s - loss: 1.5357e-05 - 6s/epoch - 10ms/step
# Epoch 201/500
# 626/626 - 6s - loss: 1.4308e-05 - 6s/epoch - 10ms/step
# Epoch 202/500
# 626/626 - 6s - loss: 1.4748e-05 - 6s/epoch - 10ms/step
# Epoch 203/500
# 626/626 - 6s - loss: 1.5613e-05 - 6s/epoch - 10ms/step
# Epoch 204/500
# 626/626 - 6s - loss: 1.5521e-05 - 6s/epoch - 10ms/step
# Epoch 205/500
# 626/626 - 6s - loss: 1.5266e-05 - 6s/epoch - 10ms/step
# Epoch 206/500
# 626/626 - 6s - loss: 1.4367e-05 - 6s/epoch - 10ms/step
# Epoch 207/500
# 626/626 - 6s - loss: 1.5202e-05 - 6s/epoch - 10ms/step
# Epoch 208/500
# 626/626 - 6s - loss: 1.4528e-05 - 6s/epoch - 10ms/step
# Epoch 209/500
# 626/626 - 6s - loss: 1.3458e-05 - 6s/epoch - 10ms/step
# Epoch 210/500
# 626/626 - 6s - loss: 1.3901e-05 - 6s/epoch - 9ms/step
# Epoch 211/500
# 626/626 - 6s - loss: 1.4227e-05 - 6s/epoch - 10ms/step
# Epoch 212/500
# 626/626 - 6s - loss: 1.4220e-05 - 6s/epoch - 10ms/step
# Epoch 213/500
# 626/626 - 6s - loss: 1.5822e-05 - 6s/epoch - 10ms/step
# Epoch 214/500
# 626/626 - 6s - loss: 1.3656e-05 - 6s/epoch - 10ms/step
# Epoch 215/500
# 626/626 - 6s - loss: 1.4371e-05 - 6s/epoch - 10ms/step
# Epoch 216/500
# 626/626 - 6s - loss: 1.4579e-05 - 6s/epoch - 10ms/step
# Epoch 217/500
# 626/626 - 6s - loss: 1.3817e-05 - 6s/epoch - 10ms/step
# Epoch 218/500
# 626/626 - 6s - loss: 1.3298e-05 - 6s/epoch - 10ms/step
# Epoch 219/500
# 626/626 - 6s - loss: 1.4834e-05 - 6s/epoch - 10ms/step
# Epoch 220/500
# 626/626 - 6s - loss: 1.3585e-05 - 6s/epoch - 10ms/step
# Epoch 221/500
# 626/626 - 6s - loss: 1.3360e-05 - 6s/epoch - 10ms/step
# Epoch 222/500
# 626/626 - 6s - loss: 1.4002e-05 - 6s/epoch - 10ms/step
# Epoch 223/500
# 626/626 - 6s - loss: 1.4064e-05 - 6s/epoch - 10ms/step
# Epoch 224/500
# 626/626 - 6s - loss: 1.4254e-05 - 6s/epoch - 10ms/step
# Epoch 225/500
# 626/626 - 6s - loss: 1.4266e-05 - 6s/epoch - 10ms/step
# Epoch 226/500
# 626/626 - 6s - loss: 1.2834e-05 - 6s/epoch - 10ms/step
# Epoch 227/500
# 626/626 - 6s - loss: 1.4693e-05 - 6s/epoch - 10ms/step
# Epoch 228/500
# 626/626 - 6s - loss: 1.4660e-05 - 6s/epoch - 10ms/step
# Epoch 229/500
# 626/626 - 6s - loss: 1.5721e-05 - 6s/epoch - 10ms/step
# Epoch 230/500
# 626/626 - 6s - loss: 1.8225e-05 - 6s/epoch - 10ms/step
# Epoch 231/500
# 626/626 - 6s - loss: 1.3422e-05 - 6s/epoch - 10ms/step
# Epoch 232/500
# 626/626 - 7s - loss: 1.3651e-05 - 7s/epoch - 10ms/step
# Epoch 233/500
# 626/626 - 6s - loss: 1.3599e-05 - 6s/epoch - 10ms/step
# Epoch 361/500
# 626/626 - 8s - loss: 1.0598e-05 - 8s/epoch - 13ms/step
# Epoch 362/500
# 626/626 - 8s - loss: 1.1590e-05 - 8s/epoch - 12ms/step
# Epoch 363/500
# 626/626 - 8s - loss: 1.0496e-05 - 8s/epoch - 12ms/step
# Epoch 364/500
# 626/626 - 8s - loss: 1.1802e-05 - 8s/epoch - 13ms/step
# Epoch 365/500
# 626/626 - 8s - loss: 1.1309e-05 - 8s/epoch - 12ms/step
# Epoch 366/500
# 626/626 - 8s - loss: 1.2344e-05 - 8s/epoch - 12ms/step
# Epoch 367/500
# 626/626 - 8s - loss: 1.1193e-05 - 8s/epoch - 12ms/step
# Epoch 368/500
# 626/626 - 8s - loss: 1.1174e-05 - 8s/epoch - 12ms/step
# Epoch 369/500
# 626/626 - 8s - loss: 1.1327e-05 - 8s/epoch - 12ms/step
# Epoch 370/500
# 626/626 - 8s - loss: 1.2145e-05 - 8s/epoch - 13ms/step
# Epoch 371/500
# 626/626 - 8s - loss: 1.3091e-05 - 8s/epoch - 12ms/step
# Epoch 372/500
# 626/626 - 8s - loss: 1.0759e-05 - 8s/epoch - 13ms/step
# Epoch 373/500
# 626/626 - 8s - loss: 1.0996e-05 - 8s/epoch - 13ms/step
# Epoch 374/500
# 626/626 - 8s - loss: 1.2575e-05 - 8s/epoch - 13ms/step
# Epoch 375/500
# 626/626 - 8s - loss: 1.1160e-05 - 8s/epoch - 13ms/step
# Epoch 376/500
# 626/626 - 8s - loss: 1.0900e-05 - 8s/epoch - 12ms/step
# Epoch 377/500
# 626/626 - 8s - loss: 1.1154e-05 - 8s/epoch - 12ms/step
# Epoch 378/500
# 626/626 - 8s - loss: 1.2126e-05 - 8s/epoch - 13ms/step
# Epoch 379/500
# 626/626 - 8s - loss: 1.2051e-05 - 8s/epoch - 13ms/step
# Epoch 380/500
# 626/626 - 8s - loss: 1.0286e-05 - 8s/epoch - 13ms/step
# Epoch 381/500
# 626/626 - 8s - loss: 1.0208e-05 - 8s/epoch - 12ms/step
# Epoch 382/500
# 626/626 - 8s - loss: 1.0464e-05 - 8s/epoch - 12ms/step
# Epoch 383/500
# 626/626 - 8s - loss: 1.1489e-05 - 8s/epoch - 12ms/step
# Epoch 384/500
# 626/626 - 8s - loss: 1.2228e-05 - 8s/epoch - 12ms/step
# Epoch 385/500
# 626/626 - 8s - loss: 1.7483e-05 - 8s/epoch - 13ms/step
# Epoch 386/500
# 626/626 - 8s - loss: 1.2714e-05 - 8s/epoch - 13ms/step
# Epoch 387/500
# 626/626 - 8s - loss: 1.2383e-05 - 8s/epoch - 12ms/step
# Epoch 388/500
# 626/626 - 8s - loss: 1.2915e-05 - 8s/epoch - 12ms/step
# Epoch 389/500
# 626/626 - 8s - loss: 1.1808e-05 - 8s/epoch - 13ms/step
# Epoch 390/500
# 626/626 - 8s - loss: 1.1615e-05 - 8s/epoch - 13ms/step
# Epoch 391/500
# 626/626 - 8s - loss: 1.1520e-05 - 8s/epoch - 13ms/step
# Epoch 392/500
# 626/626 - 8s - loss: 1.2084e-05 - 8s/epoch - 12ms/step
# Epoch 393/500
# 626/626 - 8s - loss: 1.1283e-05 - 8s/epoch - 13ms/step
# Epoch 394/500
# 626/626 - 8s - loss: 1.1751e-05 - 8s/epoch - 13ms/step
# Epoch 395/500
# 626/626 - 8s - loss: 1.2127e-05 - 8s/epoch - 13ms/step
# Epoch 396/500
# 626/626 - 8s - loss: 1.1577e-05 - 8s/epoch - 13ms/step
# Epoch 397/500
# 626/626 - 8s - loss: 1.1869e-05 - 8s/epoch - 13ms/step
# Epoch 398/500
# 626/626 - 8s - loss: 1.1055e-05 - 8s/epoch - 13ms/step
# Epoch 399/500
# 626/626 - 8s - loss: 1.0893e-05 - 8s/epoch - 13ms/step
# Epoch 400/500
# 626/626 - 8s - loss: 1.0756e-05 - 8s/epoch - 13ms/step
# Epoch 401/500
# 626/626 - 8s - loss: 1.1353e-05 - 8s/epoch - 13ms/step
# Epoch 402/500
# 626/626 - 8s - loss: 1.4045e-05 - 8s/epoch - 13ms/step
# Epoch 403/500
# 626/626 - 8s - loss: 1.1494e-05 - 8s/epoch - 13ms/step
# Epoch 404/500
# 626/626 - 8s - loss: 1.0493e-05 - 8s/epoch - 13ms/step
# Epoch 405/500
# 626/626 - 8s - loss: 1.0627e-05 - 8s/epoch - 13ms/step
# Epoch 406/500
# 626/626 - 8s - loss: 1.1463e-05 - 8s/epoch - 13ms/step
# Epoch 407/500
# 626/626 - 8s - loss: 1.1070e-05 - 8s/epoch - 13ms/step
# Epoch 408/500
# 626/626 - 8s - loss: 1.0555e-05 - 8s/epoch - 13ms/step
# Epoch 409/500
# 626/626 - 8s - loss: 1.0508e-05 - 8s/epoch - 13ms/step
# Epoch 410/500
# 626/626 - 8s - loss: 1.1314e-05 - 8s/epoch - 13ms/step
# Epoch 411/500
# 626/626 - 8s - loss: 1.0780e-05 - 8s/epoch - 13ms/step
# Epoch 412/500
# 626/626 - 8s - loss: 1.0272e-05 - 8s/epoch - 13ms/step
# Epoch 413/500
# 626/626 - 8s - loss: 1.2616e-05 - 8s/epoch - 13ms/step
# Epoch 414/500
# 626/626 - 8s - loss: 1.1182e-05 - 8s/epoch - 13ms/step
# Epoch 415/500
# 626/626 - 8s - loss: 1.0393e-05 - 8s/epoch - 13ms/step
# Epoch 416/500
# 626/626 - 8s - loss: 1.0344e-05 - 8s/epoch - 14ms/step
# Epoch 417/500
# 626/626 - 8s - loss: 1.1809e-05 - 8s/epoch - 13ms/step
# Epoch 418/500
# 626/626 - 9s - loss: 1.0882e-05 - 9s/epoch - 14ms/step
# Epoch 419/500
# 626/626 - 9s - loss: 1.2184e-05 - 9s/epoch - 14ms/step
# Epoch 420/500
# 626/626 - 8s - loss: 1.4003e-05 - 8s/epoch - 13ms/step
# Epoch 421/500
# 626/626 - 8s - loss: 1.1878e-05 - 8s/epoch - 13ms/step
# Epoch 422/500
# 626/626 - 8s - loss: 1.0982e-05 - 8s/epoch - 13ms/step
# Epoch 423/500
# 626/626 - 8s - loss: 1.0508e-05 - 8s/epoch - 13ms/step
# Epoch 424/500
# 626/626 - 8s - loss: 1.0147e-05 - 8s/epoch - 13ms/step
# Epoch 425/500
# 626/626 - 8s - loss: 1.0375e-05 - 8s/epoch - 13ms/step
# Epoch 426/500
# 626/626 - 8s - loss: 1.1097e-05 - 8s/epoch - 13ms/step
# Epoch 427/500
# 626/626 - 9s - loss: 1.1282e-05 - 9s/epoch - 14ms/step
# Epoch 428/500
# 626/626 - 8s - loss: 1.0612e-05 - 8s/epoch - 13ms/step
# Epoch 429/500
# 626/626 - 8s - loss: 1.2413e-05 - 8s/epoch - 13ms/step
# Epoch 430/500
# 626/626 - 8s - loss: 1.0768e-05 - 8s/epoch - 13ms/step
# Epoch 431/500
# 626/626 - 8s - loss: 1.1220e-05 - 8s/epoch - 13ms/step
# Epoch 432/500
# 626/626 - 8s - loss: 1.0267e-05 - 8s/epoch - 13ms/step
# Epoch 433/500
# 626/626 - 8s - loss: 1.0200e-05 - 8s/epoch - 13ms/step
# Epoch 434/500
# 626/626 - 9s - loss: 1.0087e-05 - 9s/epoch - 14ms/step
# Epoch 435/500
# 626/626 - 8s - loss: 1.0577e-05 - 8s/epoch - 13ms/step
# Epoch 436/500
# 626/626 - 8s - loss: 1.0707e-05 - 8s/epoch - 13ms/step
# Epoch 437/500
# 626/626 - 8s - loss: 1.0696e-05 - 8s/epoch - 13ms/step
# Epoch 438/500
# 626/626 - 8s - loss: 1.0286e-05 - 8s/epoch - 13ms/step
# Epoch 439/500
# 626/626 - 9s - loss: 1.0438e-05 - 9s/epoch - 14ms/step
# Epoch 440/500
# 626/626 - 8s - loss: 1.0059e-05 - 8s/epoch - 14ms/step
# Epoch 441/500
# 626/626 - 9s - loss: 1.1948e-05 - 9s/epoch - 14ms/step
# Epoch 442/500
# 626/626 - 9s - loss: 1.0334e-05 - 9s/epoch - 14ms/step
# Epoch 443/500
# 626/626 - 8s - loss: 1.1674e-05 - 8s/epoch - 13ms/step
# Epoch 444/500
# 626/626 - 8s - loss: 1.0775e-05 - 8s/epoch - 13ms/step
# Epoch 445/500
# 626/626 - 9s - loss: 1.0234e-05 - 9s/epoch - 14ms/step
# Epoch 446/500
# 626/626 - 8s - loss: 1.0692e-05 - 8s/epoch - 13ms/step
# Epoch 447/500
# 626/626 - 8s - loss: 1.0484e-05 - 8s/epoch - 14ms/step
# Epoch 448/500
# 626/626 - 9s - loss: 1.1611e-05 - 9s/epoch - 14ms/step
# Epoch 449/500
# 626/626 - 9s - loss: 1.0513e-05 - 9s/epoch - 14ms/step
# Epoch 450/500
# 626/626 - 8s - loss: 1.0829e-05 - 8s/epoch - 13ms/step
# Epoch 451/500
# 626/626 - 9s - loss: 1.0163e-05 - 9s/epoch - 14ms/step
# Epoch 452/500
# 626/626 - 8s - loss: 9.8602e-06 - 8s/epoch - 13ms/step
# Epoch 453/500
# 626/626 - 9s - loss: 1.0995e-05 - 9s/epoch - 14ms/step
# Epoch 454/500
# 626/626 - 9s - loss: 1.0611e-05 - 9s/epoch - 14ms/step
# Epoch 455/500
# 626/626 - 8s - loss: 1.0789e-05 - 8s/epoch - 13ms/step
# Epoch 456/500
# 626/626 - 8s - loss: 1.0455e-05 - 8s/epoch - 13ms/step
# Epoch 457/500
# 626/626 - 8s - loss: 1.0940e-05 - 8s/epoch - 13ms/step
# Epoch 458/500
# 626/626 - 8s - loss: 1.0082e-05 - 8s/epoch - 13ms/step
# Epoch 459/500
# 626/626 - 9s - loss: 1.1002e-05 - 9s/epoch - 14ms/step
# Epoch 460/500
# 626/626 - 9s - loss: 1.0217e-05 - 9s/epoch - 14ms/step
# Epoch 461/500
# 626/626 - 9s - loss: 1.2243e-05 - 9s/epoch - 14ms/step
# Epoch 462/500
# 626/626 - 9s - loss: 1.3494e-05 - 9s/epoch - 14ms/step
# Epoch 463/500
# 626/626 - 9s - loss: 1.1596e-05 - 9s/epoch - 14ms/step
# Epoch 464/500
# 626/626 - 9s - loss: 1.0884e-05 - 9s/epoch - 14ms/step
# Epoch 465/500
# 626/626 - 9s - loss: 1.0918e-05 - 9s/epoch - 14ms/step
# Epoch 466/500
# 626/626 - 9s - loss: 1.1137e-05 - 9s/epoch - 14ms/step
# Epoch 467/500
# 626/626 - 9s - loss: 1.4240e-05 - 9s/epoch - 14ms/step
# Epoch 468/500
# 626/626 - 9s - loss: 1.1838e-05 - 9s/epoch - 14ms/step
# Epoch 469/500
# 626/626 - 9s - loss: 1.2019e-05 - 9s/epoch - 14ms/step
# Epoch 470/500
# 626/626 - 9s - loss: 1.0816e-05 - 9s/epoch - 14ms/step
# Epoch 471/500
# 626/626 - 9s - loss: 1.0237e-05 - 9s/epoch - 14ms/step
# Epoch 472/500
# 626/626 - 9s - loss: 1.0229e-05 - 9s/epoch - 14ms/step
# Epoch 473/500
# 626/626 - 9s - loss: 1.0755e-05 - 9s/epoch - 14ms/step
# Epoch 474/500
# 626/626 - 9s - loss: 9.4275e-06 - 9s/epoch - 14ms/step
# Epoch 475/500
# 626/626 - 9s - loss: 1.1934e-05 - 9s/epoch - 14ms/step
# Epoch 476/500
# 626/626 - 9s - loss: 1.0795e-05 - 9s/epoch - 14ms/step
# Epoch 477/500
# 626/626 - 9s - loss: 1.0898e-05 - 9s/epoch - 14ms/step
# Epoch 478/500
# 626/626 - 9s - loss: 1.0171e-05 - 9s/epoch - 14ms/step
# Epoch 479/500
# 626/626 - 9s - loss: 1.0563e-05 - 9s/epoch - 14ms/step
# Epoch 480/500
# 626/626 - 9s - loss: 1.1434e-05 - 9s/epoch - 14ms/step
# Epoch 481/500
# 626/626 - 9s - loss: 9.9434e-06 - 9s/epoch - 14ms/step
# Epoch 482/500
# 626/626 - 9s - loss: 9.5256e-06 - 9s/epoch - 14ms/step
# Epoch 483/500
# 626/626 - 9s - loss: 1.0904e-05 - 9s/epoch - 14ms/step
# Epoch 484/500
# 626/626 - 9s - loss: 9.5573e-06 - 9s/epoch - 14ms/step
# Epoch 485/500
# 626/626 - 9s - loss: 9.8841e-06 - 9s/epoch - 14ms/step
# Epoch 486/500
# 626/626 - 9s - loss: 1.1003e-05 - 9s/epoch - 14ms/step
# Epoch 487/500
# 626/626 - 9s - loss: 1.5196e-05 - 9s/epoch - 14ms/step
# Epoch 488/500
# 626/626 - 9s - loss: 1.5869e-05 - 9s/epoch - 14ms/step
# Epoch 489/500
# 626/626 - 9s - loss: 1.2444e-05 - 9s/epoch - 14ms/step
# Epoch 490/500
# 626/626 - 9s - loss: 1.1726e-05 - 9s/epoch - 14ms/step
# Epoch 491/500
# 626/626 - 9s - loss: 1.0949e-05 - 9s/epoch - 14ms/step
# Epoch 492/500
# 626/626 - 9s - loss: 1.0194e-05 - 9s/epoch - 14ms/step
# Epoch 493/500
# 626/626 - 9s - loss: 9.9990e-06 - 9s/epoch - 15ms/step
# Epoch 494/500
# 626/626 - 9s - loss: 9.5086e-06 - 9s/epoch - 14ms/step
# Epoch 495/500
# 626/626 - 9s - loss: 1.0219e-05 - 9s/epoch - 15ms/step
# Epoch 496/500
# 626/626 - 9s - loss: 9.5807e-06 - 9s/epoch - 15ms/step
# Epoch 497/500
# 626/626 - 9s - loss: 1.0542e-05 - 9s/epoch - 14ms/step
# Epoch 498/500
# 626/626 - 9s - loss: 1.0726e-05 - 9s/epoch - 14ms/step
# Epoch 499/500
# 626/626 - 9s - loss: 9.9024e-06 - 9s/epoch - 14ms/step
# Epoch 500/500
# 626/626 - 9s - loss: 9.3946e-06 - 9s/epoch - 14ms/step

# %%
model.save('./NN_model')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./NN_model\assets
# INFO:tensorflow:Assets written to: ./NN_model\assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x000001D98CB9AE80> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x000001D9FF6AB370> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
# test data 
test_data = SNP_price[train_size - time_step:, :]
test_data_mul = SNP_attributes[train_size - time_step:, :]
test_data_mul_full = SNP_attributes[:, :]
# test_data_mul = np.array(test_data_mul)
X_test = []
X_test_mul = []
X_test_mul_full = []
y_test = SNP_price[train_size:, :]

for i in range(time_step, len(test_data)):
    X_test.append(test_data[i-time_step:i,0])

for i in range(time_step, len(test_data_mul)):
    X_test_mul.append(test_data_mul[i-time_step:i,0:test_data_mul.shape[1]])

for i in range(time_step, len(test_data_mul_full)):
    X_test_mul_full.append(test_data_mul_full[i-time_step:i,0:test_data_mul_full.shape[1]])


X_test, X_test_mul, X_test_mul_full = np.array(X_test), np.array(X_test_mul), np.array(X_test_mul_full)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
X_test_mul = np.reshape(X_test_mul, (X_test_mul.shape[0], X_test_mul.shape[1], X_test_mul.shape[2]))
X_test_mul_full = np.reshape(X_test_mul_full, (X_test_mul_full.shape[0], X_test_mul_full.shape[1], X_test_mul_full.shape[2]))

# %%
# predicted_price = model.predict(X_test)
predicted_price_mul = model.predict(X_test_mul)
# predicted_price = Price_scaler.inverse_transform(predicted_price)
predicted_price_mul = np.repeat(predicted_price_mul,X_test_mul.shape[2],axis=-1)
predicted_price_mul = scaler.inverse_transform(predicted_price_mul)[:,0]

predict_full = model.predict(X_test_mul_full)
predict_full = np.repeat(predict_full,X_test_mul_full.shape[2], axis=-1)
predict_full = scaler.inverse_transform(predict_full)[:,0]

# %%
plt.figure(figsize=(20,10))
training = SNP[:]
# valid = SNP[train_size:]
# valid['pred'] = predicted_price_mul
projection = predict_full

#plot
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.plot(training["Close"], label = 'Actual closing price')
# plt.plot(valid[['Closing Price', 'pred']])
plt.plot(projection, label = 'projected closing price')
plt.legend()
plt.show()

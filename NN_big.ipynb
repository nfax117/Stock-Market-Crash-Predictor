# %%
import math
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import tensorflow as tf
from keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Preprocessing

# %%
# Hyperparameters

# y column normalize scaler
normalizer_constant = 2

# time series step size
time_step = 45

# NN parameters
learning_rate = 0.1
num_epoch = 500
NN_layer_dimension = [100,100]
train_size = 568 # 80% of the data

# %%
# SNP = pd.read_csv('./SP500.csv')
SNP = pd.read_csv('./SPX_500_Data.csv')
SNP = SNP.drop(['Adj Close', 'Date','% Gain/Loss (Close)','% Price Variation'], axis=1)
# get all attributes
SNP_attributes = SNP.iloc[:,:]
# get last column (y)
# SNP_price = SNP.iloc[:,4:]
SNP_price = SNP['Close']
SNP_price = np.array(SNP_price)
SNP_price = np.reshape(SNP_price, (-1,1))

# normalize the data using MinMax scaller
scaler = MinMaxScaler()
scaler.fit(SNP_attributes)
SNP_attributes = scaler.transform(SNP_attributes)

Price_scaler = MinMaxScaler()
Price_scaler.fit(SNP_price)
SNP_price = Price_scaler.transform(SNP_price)


# scale data to [0,1]
# SNP_price = (SNP_price-SNP_price.min())/((SNP_price.max()*normalizer_constant)-SNP_price.min())

train_data = SNP_price[:, :]

train_data_mul = SNP_attributes[:, :]
# train_data_mul = np.array(train_data_mul)





# univariate
def create_train_data(data):
    x = []
    y = []
    for i in range(time_step, len(data)):
        x.append(data[i-time_step:i,0])
        y.append(data[i,0])
    return x, y

# multivariate
def create_train_data_mul(data):
    x = []
    y = []
    for i in range(time_step, len(data)):
        x.append(data[i-time_step:i, 0:data.shape[1]])
        # closing price located at the 4th column in the data set, thus '3' column
        y.append(data[i:i+1,3])
    return x, y

X_train, y_train = create_train_data(train_data_mul)
#X_train, y_train = create_train_data_mul(train_data_mul)

# %%
# Reshaping 
X_train, y_train = np.array(X_train), np.array(y_train)
#X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
# NN 
def create_model(units=[12,3], learning_rate=0.3):
    model = tf.keras.models.Sequential()
    # LSTM RNN model
    model.add(LSTM(units=64,return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Dropout(0.2))
    model.add(LSTM(units=64,return_sequences=False))
    model.add(Dropout(0.2))
    model.add(Dense(32,activation='tanh'))
    model.add(Dense(1))

    # opt = tf.keras.optimizers.SGD(learning_rate=0.1,momentum=0.9)
    model.compile(optimizer='adam',loss='mean_squared_error')

    return model

model = create_model(units=NN_layer_dimension, learning_rate=learning_rate)

# %%
# Train
model.fit(X_train, y_train, epochs=num_epoch, batch_size=36, verbose=2)
# Out:
# Epoch 1/500
# 417/417 - 11s - loss: 0.0011 - 11s/epoch - 26ms/step
# Epoch 2/500
# 417/417 - 9s - loss: 3.4702e-04 - 9s/epoch - 21ms/step
# Epoch 3/500
# 417/417 - 9s - loss: 2.9644e-04 - 9s/epoch - 21ms/step
# Epoch 4/500
# 417/417 - 9s - loss: 3.0767e-04 - 9s/epoch - 21ms/step
# Epoch 5/500
# 417/417 - 9s - loss: 2.9476e-04 - 9s/epoch - 21ms/step
# Epoch 6/500
# 417/417 - 9s - loss: 2.9427e-04 - 9s/epoch - 21ms/step
# Epoch 7/500
# 417/417 - 9s - loss: 2.8129e-04 - 9s/epoch - 21ms/step
# Epoch 8/500
# 417/417 - 9s - loss: 2.8507e-04 - 9s/epoch - 21ms/step
# Epoch 9/500
# 417/417 - 9s - loss: 2.7375e-04 - 9s/epoch - 21ms/step
# Epoch 10/500
# 417/417 - 9s - loss: 2.8344e-04 - 9s/epoch - 21ms/step
# Epoch 11/500
# 417/417 - 9s - loss: 2.5189e-04 - 9s/epoch - 21ms/step
# Epoch 12/500
# 417/417 - 9s - loss: 2.8007e-04 - 9s/epoch - 21ms/step
# Epoch 13/500
# 417/417 - 9s - loss: 2.5211e-04 - 9s/epoch - 21ms/step
# Epoch 14/500
# 417/417 - 9s - loss: 3.1271e-04 - 9s/epoch - 21ms/step
# Epoch 15/500
# 417/417 - 9s - loss: 2.2758e-04 - 9s/epoch - 21ms/step
# Epoch 16/500
# 417/417 - 9s - loss: 2.4167e-04 - 9s/epoch - 21ms/step
# Epoch 17/500
# 417/417 - 9s - loss: 2.3756e-04 - 9s/epoch - 21ms/step
# Epoch 18/500
# 417/417 - 9s - loss: 2.3171e-04 - 9s/epoch - 21ms/step
# Epoch 19/500
# 417/417 - 9s - loss: 2.5624e-04 - 9s/epoch - 21ms/step
# Epoch 20/500
# 417/417 - 9s - loss: 2.0768e-04 - 9s/epoch - 21ms/step
# Epoch 21/500
# 417/417 - 9s - loss: 2.1113e-04 - 9s/epoch - 21ms/step
# Epoch 22/500
# 417/417 - 9s - loss: 2.1199e-04 - 9s/epoch - 21ms/step
# Epoch 23/500
# 417/417 - 9s - loss: 2.1375e-04 - 9s/epoch - 21ms/step
# Epoch 24/500
# 417/417 - 9s - loss: 1.9299e-04 - 9s/epoch - 21ms/step
# Epoch 25/500
# 417/417 - 9s - loss: 1.8156e-04 - 9s/epoch - 21ms/step
# Epoch 26/500
# 417/417 - 9s - loss: 1.7857e-04 - 9s/epoch - 21ms/step
# Epoch 27/500
# 417/417 - 9s - loss: 1.8640e-04 - 9s/epoch - 21ms/step
# Epoch 28/500
# 417/417 - 9s - loss: 1.8895e-04 - 9s/epoch - 21ms/step
# Epoch 29/500
# 417/417 - 9s - loss: 1.8317e-04 - 9s/epoch - 21ms/step
# Epoch 30/500
# 417/417 - 9s - loss: 1.6553e-04 - 9s/epoch - 21ms/step
# Epoch 31/500
# 417/417 - 9s - loss: 1.7280e-04 - 9s/epoch - 22ms/step
# Epoch 32/500
# 417/417 - 7s - loss: 1.4308e-04 - 7s/epoch - 18ms/step
# Epoch 33/500
# 417/417 - 9s - loss: 1.6050e-04 - 9s/epoch - 21ms/step
# Epoch 34/500
# 417/417 - 9s - loss: 1.5619e-04 - 9s/epoch - 21ms/step
# Epoch 35/500
# 417/417 - 9s - loss: 1.5387e-04 - 9s/epoch - 21ms/step
# Epoch 36/500
# 417/417 - 9s - loss: 1.3547e-04 - 9s/epoch - 21ms/step
# Epoch 37/500
# 417/417 - 9s - loss: 1.4035e-04 - 9s/epoch - 21ms/step
# Epoch 38/500
# 417/417 - 9s - loss: 1.3245e-04 - 9s/epoch - 21ms/step
# Epoch 39/500
# 417/417 - 10s - loss: 2.7115e-05 - 10s/epoch - 24ms/step
# Epoch 408/500
# 417/417 - 10s - loss: 2.4978e-05 - 10s/epoch - 24ms/step
# Epoch 409/500
# 417/417 - 10s - loss: 2.5445e-05 - 10s/epoch - 24ms/step
# Epoch 410/500
# 417/417 - 10s - loss: 2.6359e-05 - 10s/epoch - 24ms/step
# Epoch 411/500
# 417/417 - 10s - loss: 2.6142e-05 - 10s/epoch - 24ms/step
# Epoch 412/500
# 417/417 - 10s - loss: 2.5675e-05 - 10s/epoch - 23ms/step
# Epoch 413/500
# 417/417 - 10s - loss: 2.4453e-05 - 10s/epoch - 24ms/step
# Epoch 414/500
# 417/417 - 10s - loss: 2.5914e-05 - 10s/epoch - 23ms/step
# Epoch 415/500
# 417/417 - 10s - loss: 2.5604e-05 - 10s/epoch - 24ms/step
# Epoch 416/500
# 417/417 - 10s - loss: 2.6673e-05 - 10s/epoch - 23ms/step
# Epoch 417/500
# 417/417 - 10s - loss: 2.3304e-05 - 10s/epoch - 23ms/step
# Epoch 418/500
# 417/417 - 10s - loss: 2.4247e-05 - 10s/epoch - 23ms/step
# Epoch 419/500
# 417/417 - 10s - loss: 2.6210e-05 - 10s/epoch - 24ms/step
# Epoch 420/500
# 417/417 - 10s - loss: 2.4708e-05 - 10s/epoch - 23ms/step
# Epoch 421/500
# 417/417 - 10s - loss: 2.3664e-05 - 10s/epoch - 23ms/step
# Epoch 422/500
# 417/417 - 10s - loss: 2.5381e-05 - 10s/epoch - 23ms/step
# Epoch 423/500
# 417/417 - 9s - loss: 2.5058e-05 - 9s/epoch - 22ms/step
# Epoch 424/500
# 417/417 - 10s - loss: 2.3312e-05 - 10s/epoch - 23ms/step
# Epoch 425/500
# 417/417 - 10s - loss: 2.5300e-05 - 10s/epoch - 23ms/step
# Epoch 426/500
# 417/417 - 10s - loss: 2.4763e-05 - 10s/epoch - 24ms/step
# Epoch 427/500
# 417/417 - 10s - loss: 2.4975e-05 - 10s/epoch - 23ms/step
# Epoch 428/500
# 417/417 - 10s - loss: 2.3914e-05 - 10s/epoch - 24ms/step
# Epoch 429/500
# 417/417 - 10s - loss: 2.3378e-05 - 10s/epoch - 24ms/step
# Epoch 430/500
# 417/417 - 10s - loss: 3.3199e-05 - 10s/epoch - 23ms/step
# Epoch 431/500
# 417/417 - 10s - loss: 2.5772e-05 - 10s/epoch - 23ms/step
# Epoch 432/500
# 417/417 - 10s - loss: 2.4172e-05 - 10s/epoch - 23ms/step
# Epoch 433/500
# 417/417 - 10s - loss: 2.2898e-05 - 10s/epoch - 23ms/step
# Epoch 434/500
# 417/417 - 10s - loss: 2.4389e-05 - 10s/epoch - 23ms/step
# Epoch 435/500
# 417/417 - 10s - loss: 2.3066e-05 - 10s/epoch - 23ms/step
# Epoch 436/500
# 417/417 - 10s - loss: 2.2951e-05 - 10s/epoch - 23ms/step
# Epoch 437/500
# 417/417 - 9s - loss: 2.4375e-05 - 9s/epoch - 23ms/step
# Epoch 438/500
# 417/417 - 10s - loss: 2.2257e-05 - 10s/epoch - 23ms/step
# Epoch 439/500
# 417/417 - 10s - loss: 2.4398e-05 - 10s/epoch - 23ms/step
# Epoch 440/500
# 417/417 - 10s - loss: 2.2470e-05 - 10s/epoch - 23ms/step
# Epoch 441/500
# 417/417 - 10s - loss: 2.3445e-05 - 10s/epoch - 24ms/step
# Epoch 442/500
# 417/417 - 10s - loss: 2.3980e-05 - 10s/epoch - 23ms/step
# Epoch 443/500
# 417/417 - 10s - loss: 2.2972e-05 - 10s/epoch - 23ms/step
# Epoch 444/500
# 417/417 - 10s - loss: 2.3266e-05 - 10s/epoch - 23ms/step
# Epoch 445/500
# 417/417 - 10s - loss: 2.2750e-05 - 10s/epoch - 23ms/step
# Epoch 446/500
# 417/417 - 10s - loss: 2.2271e-05 - 10s/epoch - 23ms/step
# Epoch 447/500
# 417/417 - 10s - loss: 2.3326e-05 - 10s/epoch - 23ms/step
# Epoch 448/500
# 417/417 - 10s - loss: 2.3965e-05 - 10s/epoch - 23ms/step
# Epoch 449/500
# 417/417 - 10s - loss: 2.4099e-05 - 10s/epoch - 24ms/step
# Epoch 450/500
# 417/417 - 10s - loss: 2.2854e-05 - 10s/epoch - 24ms/step
# Epoch 451/500
# 417/417 - 10s - loss: 2.3240e-05 - 10s/epoch - 23ms/step
# Epoch 452/500
# 417/417 - 10s - loss: 2.2923e-05 - 10s/epoch - 23ms/step
# Epoch 453/500
# 417/417 - 10s - loss: 2.3652e-05 - 10s/epoch - 23ms/step
# Epoch 454/500
# 417/417 - 10s - loss: 2.4449e-05 - 10s/epoch - 23ms/step
# Epoch 455/500
# 417/417 - 10s - loss: 2.1507e-05 - 10s/epoch - 24ms/step
# Epoch 456/500
# 417/417 - 9s - loss: 2.3082e-05 - 9s/epoch - 23ms/step
# Epoch 457/500
# 417/417 - 10s - loss: 2.2234e-05 - 10s/epoch - 23ms/step
# Epoch 458/500
# 417/417 - 10s - loss: 2.2516e-05 - 10s/epoch - 23ms/step
# Epoch 459/500
# 417/417 - 9s - loss: 2.2203e-05 - 9s/epoch - 23ms/step
# Epoch 460/500
# 417/417 - 9s - loss: 2.2497e-05 - 9s/epoch - 23ms/step
# Epoch 461/500
# 417/417 - 10s - loss: 2.2577e-05 - 10s/epoch - 23ms/step
# Epoch 462/500
# 417/417 - 10s - loss: 2.1345e-05 - 10s/epoch - 23ms/step
# Epoch 463/500
# 417/417 - 10s - loss: 2.3721e-05 - 10s/epoch - 23ms/step
# Epoch 464/500
# 417/417 - 10s - loss: 2.2035e-05 - 10s/epoch - 23ms/step
# Epoch 465/500
# 417/417 - 10s - loss: 2.4211e-05 - 10s/epoch - 23ms/step
# Epoch 466/500
# 417/417 - 10s - loss: 2.0769e-05 - 10s/epoch - 23ms/step
# Epoch 467/500
# 417/417 - 9s - loss: 2.3307e-05 - 9s/epoch - 23ms/step
# Epoch 468/500
# 417/417 - 10s - loss: 2.1281e-05 - 10s/epoch - 23ms/step
# Epoch 469/500
# 417/417 - 9s - loss: 2.1754e-05 - 9s/epoch - 22ms/step
# Epoch 470/500
# 417/417 - 9s - loss: 2.1899e-05 - 9s/epoch - 23ms/step
# Epoch 471/500
# 417/417 - 9s - loss: 2.1462e-05 - 9s/epoch - 23ms/step
# Epoch 472/500
# 417/417 - 9s - loss: 2.1227e-05 - 9s/epoch - 23ms/step
# Epoch 473/500
# 417/417 - 10s - loss: 2.1722e-05 - 10s/epoch - 23ms/step
# Epoch 474/500
# 417/417 - 10s - loss: 2.2164e-05 - 10s/epoch - 23ms/step
# Epoch 475/500
# 417/417 - 10s - loss: 2.2801e-05 - 10s/epoch - 23ms/step
# Epoch 476/500
# 417/417 - 10s - loss: 2.3140e-05 - 10s/epoch - 23ms/step
# Epoch 477/500
# 417/417 - 10s - loss: 2.1647e-05 - 10s/epoch - 23ms/step
# Epoch 478/500
# 417/417 - 10s - loss: 2.2539e-05 - 10s/epoch - 23ms/step
# Epoch 479/500
# 417/417 - 9s - loss: 2.1935e-05 - 9s/epoch - 23ms/step
# Epoch 480/500
# 417/417 - 10s - loss: 2.2040e-05 - 10s/epoch - 23ms/step
# Epoch 481/500
# 417/417 - 10s - loss: 2.2649e-05 - 10s/epoch - 23ms/step
# Epoch 482/500
# 417/417 - 10s - loss: 2.2487e-05 - 10s/epoch - 23ms/step
# Epoch 483/500
# 417/417 - 10s - loss: 2.0298e-05 - 10s/epoch - 23ms/step
# Epoch 484/500
# 417/417 - 10s - loss: 2.1752e-05 - 10s/epoch - 23ms/step
# Epoch 485/500
# 417/417 - 10s - loss: 2.0692e-05 - 10s/epoch - 23ms/step
# Epoch 486/500
# 417/417 - 10s - loss: 2.1336e-05 - 10s/epoch - 23ms/step
# Epoch 487/500
# 417/417 - 10s - loss: 2.1614e-05 - 10s/epoch - 24ms/step
# Epoch 488/500
# 417/417 - 10s - loss: 2.0225e-05 - 10s/epoch - 23ms/step
# Epoch 489/500
# 417/417 - 10s - loss: 2.1427e-05 - 10s/epoch - 23ms/step
# Epoch 490/500
# 417/417 - 10s - loss: 2.1179e-05 - 10s/epoch - 23ms/step
# Epoch 491/500
# 417/417 - 10s - loss: 2.0514e-05 - 10s/epoch - 23ms/step
# Epoch 492/500
# 417/417 - 10s - loss: 2.1326e-05 - 10s/epoch - 23ms/step
# Epoch 493/500
# 417/417 - 10s - loss: 2.4979e-05 - 10s/epoch - 23ms/step
# Epoch 494/500
# 417/417 - 10s - loss: 2.2924e-05 - 10s/epoch - 23ms/step
# Epoch 495/500
# 417/417 - 9s - loss: 2.1149e-05 - 9s/epoch - 23ms/step
# Epoch 496/500
# 417/417 - 10s - loss: 2.1400e-05 - 10s/epoch - 23ms/step
# Epoch 497/500
# 417/417 - 9s - loss: 1.9949e-05 - 9s/epoch - 23ms/step
# Epoch 498/500
# 417/417 - 10s - loss: 2.3214e-05 - 10s/epoch - 23ms/step
# Epoch 499/500
# 417/417 - 10s - loss: 2.0126e-05 - 10s/epoch - 23ms/step
# Epoch 500/500
# 417/417 - 10s - loss: 2.0419e-05 - 10s/epoch - 23ms/step

# %%
model = tf.keras.models.load_model('./NN_FULL__UNIVARIATE_model')
#model = tf.keras.models.load_model('./NN_FULL__MULTIVARIATE_model')

# %%
#model.save('./NN_full_multivariate_model')
model.save_weights('model_weights_uniBIG.h5')
json_string = model.to_json()
f = open("model_architecture_uniBIG.json",'w')
f.write(json_string)
f.close()

# %%
# test data 
test_data = SNP_price[train_size - time_step:, :]
test_data_full = SNP_price[:, :]
test_data_mul = SNP_attributes[train_size - time_step:, :]
test_data_mul_full = SNP_attributes[:, :]
# test_data_mul = np.array(test_data_mul)
X_test = []
X_test_full = []
X_test_mul = []
X_test_mul_full = []
y_test = SNP_price[train_size:, :]

for i in range(time_step, len(test_data)):
    X_test.append(test_data[i-time_step:i,0])

for i in range(time_step, len(test_data_mul)):
    X_test_mul.append(test_data_mul[i-time_step:i,0:test_data_mul.shape[1]])

for i in range(time_step, len(test_data_mul_full)):
    X_test_mul_full.append(test_data_mul_full[i-time_step:i,0:test_data_mul_full.shape[1]])

for i in range(time_step, len(test_data_full)):
    X_test_full.append(test_data_full[i-time_step:i,0:test_data_full.shape[1]])


X_test, X_test_mul, X_test_mul_full = np.array(X_test), np.array(X_test_mul), np.array(X_test_mul_full)
X_test_full = np.array(X_test_full,dtype=float)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
X_test_mul = np.reshape(X_test_mul, (X_test_mul.shape[0], X_test_mul.shape[1], X_test_mul.shape[2]))
X_test_mul_full = np.reshape(X_test_mul_full, (X_test_mul_full.shape[0], X_test_mul_full.shape[1], X_test_mul_full.shape[2]))
X_test_full = np.reshape(X_test_full, (X_test_full.shape[0], X_test_full.shape[1], X_test_full.shape[2]))

# %%
# predicted_price = model.predict(X_test)
predicted_price_mul = model.predict(X_test_mul_full)
# predicted_price = Price_scaler.inverse_transform(predicted_price)
predicted_price_mul_transform = np.repeat(predicted_price_mul,X_test_mul_full.shape[2],axis=-1)
predicted_price_mul_transform = scaler.inverse_transform(predicted_price_mul_transform)[:,0]

# predict_full = model.predict(X_test_full)
# # predict_full = np.repeat(predict_full,X_test_mul_full.shape[2], axis=-1)
# predict_full_transform = Price_scaler.inverse_transform(predict_full)[:,0]

# %%
plt.figure(figsize=(20,10))
training = SNP[:]
# valid = SNP[train_size:]
# valid['pred'] = predicted_price_mul
projection = predicted_price_mul_transform

#plot
plt.xlabel('Days')
plt.ylabel('Closing Price')
plt.plot(training["Close"], label = 'Actual closing price')
# plt.plot(valid[['Closing Price', 'pred']])
plt.plot(projection, label = 'projected closing price')
plt.legend()
plt.show()

# %%
# model performance metric
# MSE
print("MSE: %.10f" % (mean_squared_error(SNP_price[0:len(SNP_price)-time_step], predicted_price_mul)))
print("R2: %.5f" % (r2_score(SNP_price[0:len(SNP_price)-time_step], predicted_price_mul)))
# Out:
# MSE: 0.0002967862
# R2: 0.99200
